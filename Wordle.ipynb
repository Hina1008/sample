# %% [markdown]
# <a href="https://colab.research.google.com/github/Hina1008/sample/blob/master/Wordle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import random
import os
import copy

# %% [markdown]
# Result

# %%
class WordleResults:
  def __init__(self):
    self.max = []
    self.min = []
    self.ave = []
    self.geans = []

  def set_max(self, max):
    self.max.append(max)

  def get_max(self):
    return self.max

  def set_min(self, min):
    self.min.append(min)

  def get_min(self):
    return self.min

  def set_ave(self, ave):
    self.ave.append(ave)

  def get_ave(self):
    return self.ave

  def set_gean(self, gean):
    self.geans.append(gean)

  def get_gean(self):
    return self.geans

# %% [markdown]
# GA

# %%
class Gean:
    '''各個体のクラス
        args: 個体の持つ遺伝子情報(np.array)'''
    def __init__(self, value):
        self.value = value
        self.fitness = 0 

    def get_value(self):
      return self.value

    def set_fitness(self, fitness):
        '''個体に対する目的関数(OneMax)の値をself.fitnessに代入'''
        self.fitness = fitness

    def get_fitness(self):
        '''self.fitnessを出力'''
        return self.fitness

# %%
class Token():
  def __init__(self):
    self.small_alphabet = [i for i in range(97, 97+26)]
    self.large_alphabet = [i for i in range(65, 65+26)]

  def getAlphabets(self):
    return self.small_alphabet + self.large_alphabet

  """
  ascii ⇨ chr
  """
  def encode(self, ord):
    return chr(ord)

  def decode(self, chr):
    return ord(chr)

# %%
from typing_extensions import ParamSpecKwargs
from IPython.lib.security import passwd_check
from enum import Enum

class EvalType(Enum):
    ONLY_PERFECT_MATCH="only_perfect_match"
    INCLUDE_PARTIAL_MATCH="include_partial_match"

class OnlyPerfectMatch:
  def calc(self, target, gean):
    value = 0
    for chr1, chr2 in zip(target, gean):
      if chr1 == chr2:
        value += 1
    return value

class SameWordMatch:

  def calc(self, target, gean):
    value = 0
    for chr in target:
      if chr in gean:
        value += 1
        gean.remove(chr)
    return value/len(target)

class IncludePartialMatch:
  def __init__(self):
    self.only_perfect_match = OnlyPerfectMatch()
    self.same_word_match = SameWordMatch()

  def calc(self, target, chromesome):
    return (self.only_perfect_match.calc(target, chromesome) + self.same_word_match.calc(target, chromesome))/(len(target)+1)


class Wordle():
  def __init__(self, target, parameters, eval=EvalType.ONLY_PERFECT_MATCH):
    self.max_generation = parameters["maxGeneration"]
    self.population = parameters["population"]
    self.crossover_probability = parameters["crossover_probability"]
    self.mutation_probability = parameters["mutation_probability"]

    self.token = Token()

    self.target = [self.token.decode(word) for word in target]
    self.target_length = len(self.target)

    self.parent_geans =[]
    self.child_geans = []
    self.geans = []

    self.fitness_type = eval
    self.calc_class = {
        EvalType.ONLY_PERFECT_MATCH: OnlyPerfectMatch,
        EvalType.INCLUDE_PARTIAL_MATCH: IncludePartialMatch
    }

    self.results = WordleResults()

  """
  初期
  """
  def create_first_generation(self):
    for _ in range(self.population):
      gean = Gean(random.choices(self.token.getAlphabets(), k=self.target_length))
      gean.set_fitness(self._culc_fitness(gean))
      self.parent_geans.append(gean)
    
  # 親選択
  def create_parents_pair(self):
      parents1 = random.sample(self.parent_geans[::2], k=int(self.population/2))
      parents2 = random.sample(self.parent_geans[1::2],k=int(self.population/2))
      return parents1, parents2
  
  # 二点交叉
  def two_point_cross(self, parent1, parent2):
    #交叉点p1, p2
    first_point = random.randint(0, self.target_length-1)
    second_point = random.randint(0, self.target_length-1)

    # 交叉点の小さい方をfirst_pointとする
    if first_point > second_point:
      first_point, second_point = second_point, first_point

    child1 = Gean(parent1[0:first_point] + parent2[first_point:second_point] + parent1[second_point:])
    child1.set_fitness(self._culc_fitness(child1))
    self.child_geans.append(child1)

    child2 = Gean(parent2[0:first_point] + parent1[first_point:second_point] + parent2[second_point:])
    child2.set_fitness(self._culc_fitness(child2))
    self.child_geans.append(child2)

  def mutation(self, parent):
    index = random.randint(0,self.target_length-1)
    print(parent)
    print(index)
    parent[index] = random.choice(self.token.getAlphabets())
    child = Gean(parent)
    child.set_fitness(self._culc_fitness(child))
    self.child_geans.append(child)

  def _selection(self, geans):
    geans_arr = np.array([gean.get_fitness() for gean in geans])
    print("染色体数" + str(len(geans)))
    # print(geans_arr)
    idx = np.random.choice(np.arange(len(geans)), size=self.population, replace=False, p=geans_arr/sum(geans_arr))
    # print(idx)
    # self.child_geans = []
    return idx

  def _culc_fitness(self, gean):
    fitness = self.calc_class[self.fitness_type]().calc(self.target, copy.deepcopy(gean).get_value())
    return fitness

  def run(self):
    self.create_first_generation()
    for _ in range(self.max_generation):
      # 交叉
      parents1, parents2 = self.create_parents_pair()
      for parent1, parent2 in zip(parents1, parents2):
        if random.random() < self.crossover_probability:
          self.two_point_cross(parent1.get_value(), parent2.get_value())
      
      # 突然変異
      for parent in self.parent_geans:
        if random.random() < self.mutation_probability:
          self.mutation(parent.get_value())

      chromesomes = self.parent_geans + self.child_geans

      self.results.set_min(min([gean.get_fitness() for gean in (self.parent_geans + self.child_geans)]))
      self.results.set_max(max([gean.get_fitness() for gean in (self.parent_geans + self.child_geans)]))
      self.results.set_ave(sum([gean.get_fitness() for gean in (self.parent_geans + self.child_geans)])/len((self.parent_geans + self.child_geans)))
      max_index = [gean.get_fitness() for gean in (self.parent_geans + self.child_geans)].index(max([gean.get_fitness() for gean in (self.parent_geans + self.child_geans)]))
      self.results.set_gean((self.parent_geans + self.child_geans)[max_index].get_value())
      # for value in self.results.get_gean()[0]:
      #   print(self.token.encode(value),end="")
      # print("("+ str(len(self.parent_geans)+len(self.child_geans)) +")")
      # print("最大値：" + str(self.results.get_max()[-1]))
      # print("最小値：" + str(self.results.get_min()[-1]))
      # print("平均値：" + str(self.results.get_ave()[-1]))
      
      idx = self._selection(self.parent_geans + self.child_geans)
      print("染色体数" + str(len(chromesomes)))
      print("ルーレット選択" + str(idx))
      self.parent_geans = [chromesomes[index] for index in idx]
      # print(len(self.parent_geans))
      self.child_geans=[]
      # print(len(self.parent_geans))
      for i in idx:
        for value in chromesomes[i].get_value():
          print(self.token.encode(value),end="")
        print("(" + str(chromesomes[i].get_fitness()) + ")")
    # for chromesome in chromesomes:
    #     print(chromesome.get_value())
    #     print(''.join([self.token.encode(gean) for gean in chromesome.get_value()]))
    #     print(chromesome.get_fitness())
    #     print("-----"*30)

# %%
# Setting=[Name, MaxGeneration, Population, EliteCount, MaxStagnationGeneration, GenesDimension ...]
settings = {
    "maxGeneration":1000,
    "population":30,
    "crossover_probability": 0.8,
    "mutation_probability": 0.2
}

wordle = Wordle("Gluegent", settings, EvalType.INCLUDE_PARTIAL_MATCH)
wordle.run()
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# Gluigint(0.75)
# Gluctenz(0.6388888888888888)
# GluMXent(0.75)
# GluBgent(0.875)
# GluGgInt(0.75)
# GluvfenM(0.75)
# GluBgenz(0.75)
# GluMgint(0.75)
# Gluvfint(0.625)
# GluCfenM(0.625)
# GFuCfeqH(0.375)
# GluCgenW(0.75)
# GluGgent(0.875)
# Gluxgint(0.75)
# GloFment(0.625)
# llukgenJ(0.6388888888888888)
# GloxtenW(0.5138888888888888)
# GlmxgenM(0.625)
# [71, 108, 117, 120, 103, 101, 104, 116]
# 2
# [71, 108, 117, 71, 103, 73, 110, 116]
# 7
# [71, 108, 117, 66, 103, 101, 110, 122]
# 1
# [71, 108, 117, 120, 103, 105, 110, 116]
# 7
# [108, 108, 117, 107, 103, 101, 110, 74]
# 0
# [71, 108, 109, 120, 103, 101, 110, 77]
# 7
# 染色体数52
# 染色体数52
# ルーレット選択[34 42 38 21 27  6 43  9 49 12 51 45  2 31 25 13  8 30 37  4  0  1 40 32
#  36 29 17  7 20 39]
# llukgent(0.75)
# Gluxgeht(0.75)
# GloFment(0.625)
# GluCfenM(0.625)
# elukgenJ(0.6388888888888888)
# Gluxgent(0.875)
# GluGgInt(0.75)
# Gluvfent(0.75)
# GluxginX(0.625)
# Gluigint(0.75)
# Glmxgeno(0.625)
# GluvfenM(0.625)
# GluCfent(0.75)
# Gluigint(0.75)
# GluxginX(0.75)
# Gluctenz(0.6388888888888888)
# GluCgent(0.875)
# GluMgint(0.75)
# Gluigenz(0.75)
# GluvfenM(0.75)
# Gluigent(0.875)
# GluCfent(0.75)
# Gluxgent(0.875)
# GluMXent(0.75)
# Gluctent(0.75)
# Glmxgeno(0.625)
# GluvfenM(0.75)
# Gluxgent(0.875)
# Gluvfint(0.625)
# Gluvfent(0.75)
# [108, 108, 117, 107, 103, 101, 110, 116]
# 3
# [71, 108, 117, 120, 103, 101, 110, 116]
# 2
# [71, 108, 117, 120, 103, 105, 110, 88]
# 7
# [71, 108, 117, 118, 102, 101, 110, 77]
# 7
# [71, 108, 117, 67, 103, 101, 110, 116]
# 4
# [71, 108, 117, 105, 103, 101, 110, 122]
# 1
# [71, 108, 117, 105, 103, 101, 110, 116]
# 2
# [71, 108, 117, 99, 116, 101, 110, 116]
# 1
# [71, 108, 109, 120, 103, 101, 110, 111]
# 1
# 染色体数63
# 染色体数63
# ルーレット選択[42 48 34 39 17 53 47 30 59 15 18  5 36 45  2 16 12 24 28  0 37  4 60 49
#  11  7 51 10 19 29]
# elukgenJ(0.6388888888888888)
# GluGfent(0.75)
# GloFment(0.625)
# Gluxgent(0.875)
# GluMgint(0.75)
# Gluxgent(0.875)
# Gluigint(0.75)
# GluiginM(0.625)
# GXuigenz(0.625)
# Gluctenz(0.6388888888888888)
# GXuigenz(0.75)
# Glwxgent(0.875)
# Glukgent(0.875)
# Gluigeht(0.75)
# GloFment(0.625)
# GluCOent(0.875)
# GluCfent(0.75)
# Gkuctent(0.75)
# Gluvfint(0.625)
# lluVgent(0.75)
# lluCfenM(0.5)
# elukgenJ(0.6388888888888888)
# Glkigent(0.75)
# GluvgInt(0.75)
# GluvfenH(0.625)
# Gluvfent(0.75)
# GluCtenz(0.6388888888888888)
# GCmxgeno(0.625)
# GluvfenM(0.75)
# Gluvfent(0.75)
# [71, 108, 117, 67, 102, 101, 110, 116]
# 0
# [108, 108, 117, 86, 103, 101, 110, 116]
# 0
# [101, 108, 117, 107, 103, 101, 110, 74]
# 7
# [71, 108, 117, 118, 102, 101, 110, 72]
# 6
# [71, 108, 117, 118, 102, 101, 110, 77]
# 0
# 染色体数55
# 染色体数55
# ルーレット選択[42  6  2  5 54 35 16 53  1 40 19  9 44 13 29  4 15 22 27 32 47 49 28 21
#  36 31 39  3 51 37]
# GluCgenz(0.75)
# Gluigint(0.75)
# GloFment(0.625)
# Gluxgent(0.875)
# cluvfenM(0.5)
# GluigenM(0.75)
# TluCfent(0.75)
# GluvfeEH(0.5)
# GluGfent(0.75)
# GluCfenM(0.625)
# eluVgent(0.75)
# Gluctenz(0.6388888888888888)
# GluCgent(0.875)
# Gluigeht(0.75)
# Gluvfent(0.75)
# GluMgint(0.75)
# GluCOent(0.875)
# Glkigent(0.75)
# GCmxgeno(0.625)
# GluvfenH(0.625)
# Gluigent(0.875)
# Glucmenz(0.625)
# cluvfenM(0.75)
# elukgenX(0.6388888888888888)
# GlukgenM(0.75)
# GluMgint(0.75)
# Gluvfint(0.625)
# Gluxgent(0.875)
# eluVgent(0.7638888888888888)
# eluvfenJ(0.5138888888888888)
# [71, 108, 117, 67, 103, 101, 110, 122]
# 2
# [71, 108, 111, 70, 109, 101, 110, 116]
# 4
# [71, 108, 117, 120, 103, 101, 110, 116]
# 3
# [71, 108, 117, 118, 102, 101, 110, 116]
# 1
# [71, 108, 117, 99, 109, 101, 110, 122]
# 3
# [99, 108, 117, 118, 102, 101, 110, 77]
# 4
# [71, 108, 117, 107, 103, 101, 110, 77]
# 4
# 染色体数61
# 染色体数61
# ルーレット選択[12 16 22  3  6 39 28 56 55 50 11 33 36 45 41 40 13 35 23 44 25 30 60 52
#  48 59 46  1 21 42]
# GluCgent(0.875)
# GluCOent(0.875)
# cluvXenM(0.75)
# GluJgent(0.875)
# TluCfent(0.75)
# GluifenM(0.625)
# eluVgent(0.7638888888888888)
# GluJgent(0.875)
# GloFUent(0.625)
# eluVgent(0.7638888888888888)
# Gluctenz(0.6388888888888888)
# GluMOent(0.75)
# Gluigent(0.875)
# Gluxgint(0.75)
# GluCgenz(0.75)
# Glucment(0.75)
# Gluigeht(0.75)
# GluCgint(0.75)
# elukgenX(0.6388888888888888)
# GCmigeno(0.5)
# GluMgint(0.75)
# cluvfenM(0.5)
# GlukfenM(0.625)
# GluCgenz(0.75)
# eluigent(0.7638888888888888)
# cluvXenM(0.5)
# GluvfenM(0.625)
# Gluigint(0.75)
# Gluumenz(0.625)
# Glovfent(0.625)
# [84, 108, 117, 67, 102, 101, 110, 116]
# 5
# [71, 108, 117, 105, 102, 101, 110, 77]
# 5
# [101, 108, 117, 86, 103, 101, 110, 116]
# 1
# [71, 108, 117, 77, 79, 101, 110, 116]
# 4
# [71, 108, 117, 67, 103, 101, 110, 122]
# 7
# [71, 108, 117, 99, 109, 101, 110, 116]
# 3
# [71, 108, 117, 67, 103, 105, 110, 116]
# 7
# 染色体数65
# 染色体数65
# ルーレット選択[10 46 13 47 23 41 56 40 43 15 37  7 45 54 14 24 38  8 18 17 29  1 48 16
#  33 52 21 61 39 51]
# Gluctenz(0.6388888888888888)
# GluCgent(0.875)
# Gluxgint(0.75)
# GluCgenz(0.75)
# GluCgenz(0.75)
# Gluigent(0.875)
# Gluumenz(0.625)
# eluMOent(0.6388888888888888)
# GluCfenM(0.625)
# Gluament(0.75)
# Gluxgint(0.75)
# GluJgent(0.875)
# Glovfent(0.625)
# Gluigint(0.75)
# GluCgenn(0.75)
# eluigent(0.7638888888888888)
# eluJgenX(0.6388888888888888)
# GloFUent(0.625)
# elukgenX(0.6388888888888888)
# GluCginV(0.75)
# Glovfent(0.625)
# GluCOent(0.875)
# cluvXenM(0.5)
# Gluigeht(0.75)
# GluVgent(0.875)
# GluJgent(0.875)
# cluvfenM(0.5)
# GluMEent(0.75)
# Glukgent(0.875)
# Gluigeno(0.75)
# [71, 108, 117, 120, 103, 105, 110, 116]
# 0
# [71, 108, 117, 67, 103, 101, 110, 122]
# 7
# [71, 108, 117, 105, 103, 101, 110, 116]
# 6
# [71, 108, 117, 67, 103, 101, 110, 110]
# 3
# [101, 108, 117, 74, 103, 101, 110, 88]
# 4
# [71, 108, 117, 86, 103, 101, 110, 116]
# 1
# 染色体数56
# 染色体数56
# ルーレット選択[19 50 47 34 28 24 25  9 32 17 33 11 48  8 22 31  6 44 10 23  1 45 37 16
#  38 29 54 43 20 13]
# GluCginV(0.75)
# Jluxgint(0.625)
# eluigent(0.7638888888888888)
# cluvgenM(0.625)
# Glukgent(0.875)
# GwuVgent(0.875)
# GluJgent(0.875)
# Gluament(0.75)
# cluMfenM(0.5)
# GloFUent(0.625)
# GluvEent(0.75)
# GluJgent(0.875)
# Glukgent(0.875)
# GluCfenM(0.625)
# cluvXenM(0.5)
# GluCOent(0.75)
# Gluumenz(0.625)
# Gluumenz(0.625)
# Gluxgint(0.75)
# Gluigeht(0.75)
# GluCgent(0.875)
# GluCgent(0.875)
# Gluxgint(0.75)
# eluJFenX(0.6388888888888888)
# GluCgenn(0.75)
# Gluigeno(0.75)
# eluJFenX(0.5138888888888888)
# Gluctent(0.75)
# Glovfent(0.625)
# Gluigint(0.75)
# [101, 108, 117, 105, 103, 101, 110, 116]
# 0
# [71, 108, 117, 118, 69, 101, 110, 116]
# 1
# [71, 108, 117, 67, 79, 101, 110, 116]
# 1
# [71, 108, 117, 117, 109, 101, 110, 122]
# 3
# 染色体数58
# 染色体数58
# ルーレット選択[17 32  3 40 20  5 30 12 48 14  4 11 43 52 31 55 35 54  1 41 50 22 53 37
#  27  8 46 47 23 42]
# Glummenz(0.625)
# GluCgenn(0.75)
# cluvgenM(0.625)
# cluMfenM(0.5)
# GluCgent(0.875)
# GwuVgent(0.875)
# eluigent(0.7638888888888888)
# Glukgent(0.875)
# GluvEent(0.75)
# cluvXenM(0.5)
# Glukgent(0.875)
# GluJgent(0.875)
# GluJFent(0.75)
# eluJFent(0.6388888888888888)
# Gluigeht(0.75)
# GJuvEent(0.625)
# GluCment(0.75)
# tluigent(0.75)
# Jluxgint(0.625)
# GwuVgent(0.75)
# Gluxgint(0.75)
# Gluxgint(0.75)
# GluxginX(0.625)
# Gluigeno(0.75)
# Gluctent(0.75)
# cluMfenM(0.5)
# GloCOent(0.625)
# Gluvfent(0.75)
# eluJFenX(0.6388888888888888)
# eluCgenX(0.6388888888888888)
# [99, 108, 117, 118, 103, 101, 110, 77]
# 2
# [101, 108, 117, 74, 70, 101, 110, 116]
# 5
# [116, 108, 117, 105, 103, 101, 110, 116]
# 1
# [71, 108, 117, 99, 116, 101, 110, 116]
# 1
# 染色体数62
# 染色体数62
# ルーレット選択[40 48 34 10 38 43 13 46 51 55 53  0 23  3 20 31 56 32 33  4 54 15 39 28
#  11 26  8  6 36 18]
# GJummenz(0.5)
# Jluxgent(0.75)
# Glukgent(0.875)
# Glukgent(0.875)
# GluvgenM(0.75)
# tluJFent(0.625)
# eluJFsnt(0.6388888888888888)
# GluCgent(0.875)
# GwuVgent(0.75)
# cluMfenM(0.5)
# GlovXenM(0.5)
# Glummenz(0.625)
# Gluigeno(0.75)
# cluMfenM(0.5)
# Gluxgint(0.75)
# GluCgenn(0.75)
# Gluxgint(0.75)
# GluJgent(0.875)
# GluvEent(0.75)
# GluCgent(0.875)
# eluJFenX(0.5138888888888888)
# GJuvEent(0.625)
# cluvfent(0.625)
# eluJFenX(0.6388888888888888)
# GluJgent(0.875)
# GloCOent(0.625)
# GluvEent(0.75)
# eluigent(0.7638888888888888)
# Gluifeht(0.625)
# Jluxgint(0.625)
# [99, 108, 117, 77, 102, 101, 110, 77]
# 4
# [71, 108, 111, 118, 88, 101, 110, 77]
# 4
# [71, 108, 117, 109, 109, 101, 110, 122]
# 7
# [71, 108, 117, 120, 103, 105, 110, 116]
# 7
# [71, 108, 117, 74, 103, 101, 110, 116]
# 7
# [99, 108, 117, 118, 102, 101, 110, 116]
# 0
# 染色体数58
# 染色体数58
# ルーレット選択[32  4 51 18 15 28 45 19 54 46 25  5 16 31  2 37  6 39 33 56 17 57 36  1
#  14 42 53 38  8 27]
# GlovXenM(0.5)
# GluvgenM(0.75)
# eluJginX(0.5138888888888888)
# GluvEent(0.75)
# GluCgenn(0.75)
# Gluifeht(0.625)
# Gluifent(0.75)
# GluCgent(0.875)
# Glummenp(0.625)
# cluigent(0.75)
# GloCOent(0.625)
# tluJFent(0.625)
# Gluxgint(0.75)
# Gluxgint(0.75)
# Glukgent(0.875)
# GluvEent(0.75)
# eluJFsnt(0.6388888888888888)
# Gluigent(0.875)
# Jluxgent(0.75)
# GluJgenY(0.75)
# GluJgenY(0.875)
# vluvfent(0.625)
# GluCgent(0.875)
# Jluxgent(0.75)
# Gluxgink(0.75)
# GluCgent(0.875)
# GlovLenM(0.5)
# GJuvEeno(0.5)
# GwuVgent(0.75)
# eluigent(0.7638888888888888)
# [71, 108, 111, 118, 88, 101, 110, 77]
# 3
# [71, 108, 117, 118, 69, 101, 110, 116]
# 5
# [71, 108, 117, 67, 103, 101, 110, 116]
# 2
# [118, 108, 117, 118, 102, 101, 110, 116]
# 5
# [71, 108, 117, 67, 103, 101, 110, 116]
# 7
# [74, 108, 117, 120, 103, 101, 110, 116]
# 2
# [71, 108, 117, 120, 103, 105, 110, 107]
# 0
# [101, 108, 117, 105, 103, 101, 110, 116]
# 3
# 染色体数64
# 染色体数64
# ルーレット選択[58 33 28  9 55 39 56 43 15 35 57 48 19  5 11  4 61 20 51  7 45 47 59 60
#  46 42  1 34 29 53]
# GlzCgent(0.75)
# GluiLeht(0.625)
# GwuVgent(0.75)
# cluigent(0.75)
# elovXent(0.5138888888888888)
# GlummenY(0.625)
# GloWXenM(0.5)
# GluJgint(0.75)
# GluvEent(0.75)
# Gluxgino(0.625)
# GluvELnt(0.625)
# Gluifent(0.75)
# GluJgenY(0.75)
# Gluifeht(0.625)
# tluJFent(0.625)
# GluCgenn(0.75)
# Jlrxgent(0.625)
# GluJgenY(0.875)
# vluJfent(0.625)
# GlzCgent(0.875)
# GwuVgenM(0.625)
# tlukgent(0.75)
# vluvfpnt(0.5)
# GluCgenw(0.75)
# GluJFent(0.75)
# eluCgenX(0.6388888888888888)
# GluvgenM(0.75)
# GJuvEenk(0.5)
# elungent(0.7638888888888888)
# Gluigent(0.875)
# [71, 108, 117, 105, 76, 101, 104, 116]
# 6
# [71, 108, 117, 105, 102, 101, 110, 116]
# 7
# [71, 108, 117, 74, 103, 101, 110, 89]
# 3
# [71, 108, 117, 118, 103, 101, 110, 77]
# 3
# [71, 74, 117, 118, 69, 101, 110, 107]
# 0
# 染色体数61
# 染色体数61
# ルーレット選択[45 21 10 58 12 29 33 56 48 41 46 40 38 44 55  5 17 24  0  2 28 54 19  9
#  52 11 25 42 31 30]
# GlzCgent(0.75)
# tlukgent(0.75)
# GluvELnt(0.625)
# GluHgenY(0.75)
# GluHgenY(0.75)
# Gluigent(0.875)
# tluJFenY(0.5138888888888888)
# GluiLeAt(0.625)
# GluJgent(0.875)
# GluvELnt(0.625)
# elungent(0.7638888888888888)
# Gluigent(0.875)
# Gluxgent(0.875)
# Jlrxgent(0.625)
# Glukgent(0.875)
# GlummenY(0.625)
# GluHgenY(0.875)
# GluJFent(0.75)
# GlzCgent(0.75)
# GwuVgent(0.75)
# elungent(0.7638888888888888)
# tluvEent(0.625)
# GlzCgent(0.875)
# Gluxgino(0.625)
# vluJfent(0.625)
# GluifenJ(0.75)
# eluCgenX(0.6388888888888888)
# GloWLenM(0.5)
# GJuvgenk(0.625)
# GluvEenM(0.625)
# [71, 108, 122, 67, 103, 101, 110, 116]
# 4
# [71, 108, 117, 118, 69, 76, 110, 116]
# 3
# [71, 108, 117, 105, 103, 101, 110, 116]
# 4
# [71, 108, 117, 105, 103, 101, 110, 116]
# 5
# [71, 108, 122, 67, 103, 101, 110, 116]
# 6
# [71, 108, 122, 67, 103, 101, 70, 116]
# 1
# [71, 108, 117, 120, 103, 105, 110, 111]
# 3
# [71, 74, 117, 118, 103, 101, 110, 107]
# 6
# 染色体数62
# 染色体数62
# ルーレット選択[32 27 12 55 53 25 56  4 24 11 37  3 42  0 38 16 28 35 33 17 21 14 47 19
#  18 30  2 46 51 57]
# tluigenY(0.6388888888888888)
# GloWLenM(0.5)
# Gluxgent(0.875)
# GluaELnt(0.625)
# Jluxgent(0.75)
# GluifenJ(0.75)
# Gluinent(0.75)
# GluHgenY(0.75)
# vluJfent(0.625)
# GluigAnt(0.875)
# Gluvgent(0.875)
# GluHgenY(0.75)
# GluHgenY(0.75)
# GlzCFent(0.75)
# GluJgent(0.875)
# GluHgenY(0.875)
# GJuvgewk(0.625)
# GlzCgent(0.75)
# GluJFent(0.75)
# GluJFent(0.75)
# tluvEent(0.625)
# Glukgent(0.875)
# GluvgenY(0.75)
# GwuVgent(0.75)
# GjzCgeFt(0.75)
# eluCgenX(0.6388888888888888)
# GluaELnt(0.625)
# GluHELnt(0.625)
# tluvEent(0.625)
# GluigAnt(0.75)
# [71, 108, 111, 87, 76, 101, 110, 77]
# 0
# [71, 108, 117, 105, 102, 101, 110, 74]
# 3
# 染色体数56
# 染色体数56
# ルーレット選択[ 8 11 36 19 20 55  0 41 43 25 48 17 54 49 18 32 21 10 24 14  3 37 38 53
#  27 23 31 42 39 30]
# vluJfent(0.625)
# GluHgenY(0.75)
# GluHnent(0.75)
# GluJFent(0.75)
# tluvEent(0.625)
# GluffenJ(0.625)
# tluigenY(0.6388888888888888)
# GluaELnt(0.625)
# GluvgAnt(0.75)
# eluCgenX(0.6388888888888888)
# JluCgent(0.75)
# GlzCgent(0.75)
# yloWLenM(0.375)
# eluxgenX(0.6388888888888888)
# GluJFent(0.75)
# GlzCgeFt(0.625)
# Glukgent(0.875)
# Gluvgent(0.875)
# GjzCgeFt(0.75)
# GluJgent(0.875)
# GluaELnt(0.625)
# GluigenY(0.75)
# GluJgent(0.875)
# vluJfent(0.625)
# GluHELnt(0.625)
# GwuVgent(0.75)
# GlzCEent(0.625)
# Gluigent(0.875)
# GluHgenY(0.75)
# tluvgent(0.75)
# [71, 108, 117, 72, 103, 101, 110, 89]
# 2
# [121, 108, 111, 87, 76, 101, 110, 77]
# 0
# [71, 108, 117, 107, 103, 101, 110, 116]
# 4
# [71, 106, 122, 67, 103, 101, 70, 116]
# 7
# [71, 108, 117, 97, 69, 76, 110, 116]
# 0
# 染色体数55
# 染色体数55
# ルーレット選択[31 12  3 14 34  1 13 18 35 44 46  9  8  5 49 30  4 50  2 27 20 19 21 28
#  43 17 53 54 47  0]
# GlukgenX(0.75)
# QloWLenM(0.375)
# GluJFent(0.75)
# GluJFent(0.75)
# GluHnent(0.75)
# GlbHgenY(0.75)
# eluxgenX(0.6388888888888888)
# GjzCgeFk(0.75)
# GwuVgent(0.75)
# GluCgent(0.875)
# tluvgent(0.75)
# eluCgenX(0.6388888888888888)
# GluvgAnt(0.75)
# GluffenJ(0.625)
# GluJFent(0.75)
# eluxgent(0.7638888888888888)
# tluvEent(0.625)
# GlbHgenY(0.625)
# GluHnent(0.75)
# Gluigent(0.875)
# FluaELnt(0.625)
# GluJgent(0.875)
# GluigenY(0.75)
# GluHgenY(0.75)
# GluJfLnt(0.625)
# Gluvgent(0.875)
# GjzCgeFk(0.375)
# FluaELnt(0.5)
# GluHELnt(0.625)
# vluJfent(0.625)
# [71, 108, 117, 107, 103, 101, 110, 88]
# 1
# [71, 119, 117, 86, 103, 101, 110, 116]
# 1
# [71, 108, 117, 74, 70, 101, 110, 116]
# 4
# [101, 108, 117, 120, 103, 101, 110, 116]
# 7
# [71, 108, 117, 105, 103, 101, 110, 89]
# 4
# [71, 108, 117, 72, 103, 101, 110, 89]
# 2
# [70, 108, 117, 97, 69, 76, 110, 116]
# 7
# 染色体数63
# 染色体数63
# ルーレット選択[15 39 22 34  4 21 48  6 12  9 28  7 53 44  2 62 17 42 51 57 45 19 38  0
#  56 16 47 29 50 23]
# eluxgenB(0.7638888888888888)
# GluaELnt(0.625)
# GluiaenY(0.75)
# Gluffent(0.75)
# GluHnent(0.75)
# GluJgent(0.875)
# GluJgLnt(0.75)
# eluxgenX(0.6388888888888888)
# GluvgAnt(0.75)
# GluCgent(0.875)
# GluHELnt(0.625)
# GjzCgeFk(0.75)
# GluHgenY(0.75)
# tluvgent(0.75)
# GluJFent(0.75)
# FluaELne(0.3888888888888889)
# GlbHgenY(0.625)
# GluigenY(0.75)
# eluxgent(0.7638888888888888)
# GeuVgent(0.7638888888888888)
# Gluvgent(0.875)
# Gluigent(0.875)
# FlukgenX(0.625)
# GJukgenX(0.75)
# GJukgenX(0.625)
# tluvEent(0.625)
# GluJEent(0.75)
# vluJfent(0.625)
# GjzCgeFk(0.375)
# GlYHgenY(0.75)
# [71, 108, 117, 72, 69, 76, 110, 116]
# 6
# [70, 108, 117, 107, 103, 101, 110, 88]
# 1
# [71, 108, 117, 74, 69, 101, 110, 116]
# 6
# 染色体数55
# 染色体数55
# ルーレット選択[ 7  1  5 19 49 13 18  6 38 51 32 48 36 10 31 23  8 33 27 45 15 47 29 14
#  12  9 25 54 11  0]
# eluxgenX(0.6388888888888888)
# GluaELnt(0.625)
# GluJgent(0.875)
# GeuVgent(0.7638888888888888)
# Gluigent(0.875)
# tluvgent(0.75)
# eluxgent(0.7638888888888888)
# GluJgLnt(0.75)
# GluJgent(0.875)
# GluHELnt(0.625)
# eluxgenB(0.6388888888888888)
# GJukgenX(0.625)
# Gluigent(0.875)
# GluHELgt(0.625)
# GlYHgenY(0.625)
# GJukgenX(0.75)
# GluvgAnt(0.75)
# eluxgenX(0.6388888888888888)
# vluJfent(0.625)
# Gluffent(0.75)
# FluaELne(0.3888888888888889)
# tluvEent(0.625)
# GlYHgenY(0.75)
# GluJFent(0.75)
# GluHgenY(0.75)
# GluCgent(0.875)
# tluvEent(0.625)
# GluJEeJt(0.625)
# GjzCgeFk(0.75)
# eluxgenB(0.7638888888888888)
# [118, 108, 117, 74, 102, 101, 110, 116]
# 2
# [70, 108, 117, 97, 69, 76, 110, 101]
# 3
# 染色体数56
# 染色体数56
# ルーレット選択[29 30 11  6 36 46  2 40 50  1 32 24  9 31 44 18 12 37  0 48 55 25 21 53
#  17  7 54 10 15 20]
# eluxgenB(0.7638888888888888)
# GluJgent(0.875)
# GJukgenX(0.625)
# eluxgent(0.7638888888888888)
# eluxgent(0.7638888888888888)
# eluCgenX(0.6388888888888888)
# GluJgent(0.875)
# GluJgent(0.875)
# vluvgent(0.75)
# GluaELnt(0.625)
# GJuigent(0.75)
# GluHgenY(0.75)
# GluHELnt(0.625)
# GluJgLnt(0.75)
# eluHgenB(0.6388888888888888)
# vldJfent(0.625)
# Gluigent(0.875)
# eluxgenX(0.6388888888888888)
# eluxgenX(0.6388888888888888)
# GluvgeFk(0.625)
# FluNELne(0.3888888888888889)
# GluCgent(0.875)
# tluvEent(0.625)
# GluJEeJt(0.625)
# eluxgenX(0.6388888888888888)
# GluJgLnt(0.75)
# vldJfent(0.5)
# eluxgenB(0.6388888888888888)
# GJukgenX(0.75)
# FluNELne(0.3888888888888889)
# [71, 74, 117, 105, 103, 101, 110, 116]
# 1
# [71, 108, 117, 72, 103, 101, 110, 89]
# 6
# [71, 108, 117, 72, 69, 76, 110, 116]
# 5
# [71, 108, 117, 74, 103, 76, 110, 116]
# 6
# [71, 108, 117, 105, 103, 101, 110, 116]
# 7
# [101, 108, 117, 120, 103, 101, 110, 88]
# 1
# [71, 108, 117, 67, 103, 101, 110, 116]
# 1
# [71, 108, 117, 74, 69, 101, 74, 116]
# 0
# [101, 108, 117, 120, 103, 101, 110, 88]
# 0
# [71, 74, 117, 107, 103, 101, 110, 88]
# 5
# 染色体数58
# 染色体数58
# ルーレット選択[ 2  8 36  3  4  7 17 53 20  0 54 28 22 10 48  1 33 16 14 37 30 56  6 35
#  44 39 45 40 38 21]
# GJukgenX(0.625)
# vluvgent(0.75)
# Gluigent(0.875)
# eluxgent(0.7638888888888888)
# eluxgent(0.7638888888888888)
# GluJgent(0.875)
# etuxgenX(0.6388888888888888)
# etuxgenX(0.5277777777777778)
# FluNELne(0.3888888888888889)
# eluxgenB(0.7638888888888888)
# GQuCgent(0.75)
# GJukgFnX(0.75)
# tluvEent(0.625)
# Gguigent(0.75)
# Gguigent(0.75)
# GluJgent(0.875)
# GluJgent(0.875)
# GluigenE(0.875)
# eluHgenB(0.6388888888888888)
# GluJgLnt(0.75)
# vluCgent(0.75)
# FluxgenX(0.625)
# GluJgent(0.875)
# eluxgent(0.7638888888888888)
# eluHgenB(0.6388888888888888)
# GJuigent(0.75)
# eluxgenB(0.6388888888888888)
# eluCgent(0.7638888888888888)
# GluJgent(0.875)
# GQuCgent(0.875)
# [71, 74, 117, 107, 103, 101, 110, 88]
# 1
# [101, 116, 117, 120, 103, 101, 110, 88]
# 6
# [71, 103, 117, 105, 103, 101, 110, 116]
# 0
# [101, 108, 117, 72, 103, 101, 110, 66]
# 3
# [71, 74, 117, 105, 103, 101, 110, 116]
# 5
# 染色体数61
# 染色体数61
# ルーレット選択[13 32 38 41 31 15  2 54 36  1  0 35 34 22 57 53 20  5 50  6 46 33 28 47
#  24 45 39  3 44 58]
# Uguigent(0.75)
# eluJgenX(0.6388888888888888)
# Gluxgent(0.875)
# eluigent(0.7638888888888888)
# eluHgent(0.7638888888888888)
# GluJgent(0.875)
# Gluigent(0.875)
# GguCgent(0.75)
# eluCgent(0.7638888888888888)
# vluvgent(0.75)
# GTukgenX(0.625)
# vluvgent(0.75)
# GluJgent(0.875)
# GluJgent(0.875)
# etuxgesX(0.4027777777777778)
# GJukgFnX(0.5)
# vluCgent(0.75)
# GluJgent(0.875)
# GluCgent(0.875)
# etuxgesX(0.6388888888888888)
# Gluigent(0.875)
# Gtuxgent(0.75)
# GluJgent(0.875)
# eluxgent(0.7638888888888888)
# eluHgenB(0.6388888888888888)
# GluigenE(0.75)
# etuJgenX(0.5277777777777778)
# eluxgent(0.7638888888888888)
# eluxgenB(0.6388888888888888)
# Uguigent(0.625)
# [101, 108, 117, 74, 103, 101, 110, 88]
# 1
# [101, 108, 117, 105, 103, 101, 110, 116]
# 1
# [101, 108, 117, 67, 103, 101, 110, 116]
# 6
# [101, 116, 117, 120, 103, 101, 115, 88]
# 2
# [101, 116, 73, 120, 103, 101, 115, 88]
# 3
# [71, 108, 117, 74, 103, 101, 110, 116]
# 6
# 染色体数62
# 染色体数62
# ルーレット選択[17  4 18 10 47 40 24 21 20  0 61 34 49  3 31 11  1  5  9 45 35 29 57 13
#   7 53 36 42 50 54]
# GluJgent(0.875)
# eluHgent(0.7638888888888888)
# GluCgent(0.875)
# GTukgenX(0.625)
# GJuHgenX(0.625)
# eluvgent(0.7638888888888888)
# eluHgenB(0.6388888888888888)
# Gtuxgent(0.75)
# Gluigent(0.875)
# Uguigent(0.75)
# GluJgept(0.75)
# GluJgent(0.875)
# Gluxgent(0.875)
# eauigent(0.7638888888888888)
# GluJgent(0.875)
# vluvgent(0.75)
# eouJgenX(0.6388888888888888)
# GluJgent(0.875)
# vluvgent(0.75)
# Gluigent(0.875)
# Gluxgent(0.875)
# Uguigent(0.625)
# eauigent(0.6388888888888888)
# GluJgent(0.875)
# GguCgent(0.75)
# eluxgent(0.7638888888888888)
# Gluigent(0.875)
# etuJgenX(0.5277777777777778)
# Gluxgent(0.875)
# vluCgent(0.75)
# [71, 84, 117, 107, 103, 101, 110, 88]
# 2
# [71, 74, 117, 72, 103, 101, 110, 88]
# 5
# [71, 108, 117, 74, 103, 101, 112, 116]
# 6
# [71, 108, 117, 74, 103, 101, 110, 116]
# 1
# [71, 108, 117, 74, 103, 101, 110, 116]
# 0
# [85, 103, 117, 105, 103, 101, 110, 116]
# 4
# [71, 108, 117, 105, 103, 101, 110, 116]
# 2
# 染色体数59
# 染色体数59
# ルーレット選択[50 58 32 14 10  5 15  7 11 40 55 52 29 26 38  2 42 37  8  6 44 56 41 36
#  48 16 13 18  3 39]
# GluCgent(0.875)
# GlYigent(0.75)
# GtuJgenX(0.6388888888888888)
# GyuJgent(0.875)
# GluJgedt(0.75)
# eluvgent(0.7638888888888888)
# vluvgent(0.75)
# Gtuxgent(0.75)
# GluJgent(0.875)
# vluJgent(0.75)
# GyuJgent(0.75)
# GTQkgenX(0.5)
# vluCgent(0.75)
# GlYigent(0.875)
# GTuCgent(0.75)
# GluCgent(0.875)
# eluxgenX(0.6388888888888888)
# Gluxgent(0.875)
# Gluigent(0.875)
# eluHgenB(0.6388888888888888)
# Gluvgent(0.875)
# gluJgent(0.75)
# Gluvgent(0.875)
# Gtuxgent(0.75)
# GluJgent(0.875)
# eouJgenX(0.6388888888888888)
# eauigent(0.7638888888888888)
# vluvgent(0.75)
# GTQkgenX(0.625)
# GgukgenX(0.625)
# [71, 108, 117, 67, 103, 101, 110, 116]
# 7
# [71, 108, 117, 74, 103, 101, 110, 116]
# 6
# [71, 121, 117, 74, 103, 101, 110, 116]
# 2
# [71, 84, 81, 107, 103, 101, 110, 88]
# 4
# [71, 108, 89, 105, 103, 101, 110, 116]
# 3
# [71, 108, 117, 105, 103, 101, 110, 116]
# 5
# [101, 97, 117, 105, 103, 101, 110, 116]
# 7
# [71, 84, 81, 107, 70, 101, 110, 88]
# 3
# [71, 103, 117, 107, 103, 101, 110, 88]
# 1
# 染色体数61
# 染色体数61
# ルーレット選択[ 6 19 42 51 11 59 14 37 47 41 49 28  1 24 20 48 27 39 35 60  3 52 13 38
#   7 16  5 44 12 43]
# vluvgent(0.75)
# eluHgenB(0.6388888888888888)
# Gtuxgent(0.75)
# Gluigent(0.875)
# GTQuFenX(0.5)
# GTQuFenX(0.3888888888888889)
# GTuCgent(0.75)
# GTQJgent(0.625)
# gluJgent(0.75)
# vluvgent(0.75)
# GluJgent(0.875)
# GTQuFenX(0.625)
# GlYEgent(0.75)
# GluJgent(0.875)
# Gluvgent(0.875)
# GyuJgedt(0.625)
# vluvgent(0.75)
# GlYigent(0.75)
# GluvgenX(0.75)
# GzukgenX(0.625)
# GyhJgent(0.875)
# GluCgenK(0.75)
# GlYEgent(0.875)
# GyuJgent(0.75)
# Gtuxgent(0.75)
# eluxgenX(0.6388888888888888)
# eluvgent(0.7638888888888888)
# GTQkgent(0.625)
# vluCgent(0.75)
# eauigent(0.6388888888888888)
# [71, 116, 117, 120, 103, 101, 110, 116]
# 3
# [71, 84, 81, 117, 70, 101, 110, 88]
# 4
# [71, 84, 81, 74, 103, 101, 110, 116]
# 2
# [118, 108, 117, 118, 103, 101, 110, 116]
# 0
# [71, 108, 89, 105, 103, 101, 110, 116]
# 0
# [71, 121, 104, 74, 103, 101, 110, 116]
# 6
# [71, 116, 117, 120, 103, 101, 110, 116]
# 1
# [71, 84, 81, 107, 103, 101, 110, 116]
# 5
# 染色体数60
# 染色体数60
# ルーレット選択[32 14 22 27 26 20 39 23 51 43 42 58 33  2 12 30 25 44 36 34 45 28  4 29
#  17 11  3  9 15 53]
# GluvgenX(0.75)
# Gluvgent(0.875)
# GlYEgent(0.875)
# GTQkgJnt(0.625)
# eluvgent(0.7638888888888888)
# GyhJgeht(0.875)
# GTQigent(0.625)
# GyuJgent(0.75)
# GluxgenX(0.75)
# GtQuFenX(0.4027777777777778)
# GTuxgent(0.75)
# GPuxgent(0.75)
# GluCgenK(0.75)
# Gtuwgent(0.75)
# GlYEgent(0.75)
# Gtuxgent(0.75)
# eluxgenX(0.6388888888888888)
# GyhJgent(0.625)
# GyuJgent(0.75)
# GaYEgent(0.625)
# GluJgent(0.875)
# vluCgent(0.75)
# GTQuVenX(0.5)
# eauigent(0.6388888888888888)
# plYigent(0.75)
# GTQuVenX(0.625)
# Gluigent(0.875)
# uluvgent(0.75)
# GyuJgedt(0.625)
# GTQuVenX(0.3888888888888889)
# [71, 121, 104, 74, 103, 101, 104, 116]
# 3
# [71, 84, 81, 105, 103, 101, 110, 116]
# 6
# [71, 108, 89, 69, 103, 101, 110, 116]
# 2
# [71, 121, 104, 74, 103, 101, 110, 116]
# 2
# [71, 108, 117, 105, 103, 101, 110, 116]
# 0
# 染色体数59
# 染色体数59
# ルーレット選択[12  7 42 53 39 38 44 28 35 26 15  4 47 48 31 41 13 54 51 45 21 11 24  2
#  32 18 27  8 34 23]
# GluCgenK(0.75)
# GyuJgent(0.75)
# GPuxgenX(0.625)
# Gyuvgeht(0.625)
# GluCgent(0.875)
# vluigent(0.75)
# GluuFent(0.75)
# GyuJgedt(0.625)
# uluvgent(0.75)
# Bluigent(0.875)
# Gtuxgent(0.75)
# eluvgent(0.7638888888888888)
# GyuJgent(0.75)
# GTQigent(0.625)
# GTQuVent(0.5138888888888888)
# GTQxVenX(0.375)
# Gtuwgent(0.75)
# Gyhigeht(0.5)
# GyhEgent(0.625)
# GtQJgenX(0.5138888888888888)
# vluCgent(0.75)
# GPuxgent(0.75)
# plYigent(0.75)
# GlmEgent(0.875)
# GyuJgent(0.75)
# GyuJgent(0.75)
# uluvgent(0.75)
# GluxgenX(0.75)
# plYigent(0.625)
# eauigent(0.6388888888888888)
# [71, 80, 117, 120, 103, 101, 110, 88]
# 0
# [71, 121, 117, 118, 103, 101, 104, 116]
# 6
# [118, 108, 117, 105, 103, 101, 110, 116]
# 5
# [71, 84, 81, 117, 86, 101, 110, 116]
# 6
# [71, 84, 81, 120, 86, 101, 110, 88]
# 0
# [112, 108, 89, 105, 103, 101, 110, 116]
# 6
# 染色体数58
# 染色体数58
# ルーレット選択[21 29 17 28 16 23 41  9 10  5 51 25  0 32 12  1  7 43 49  6 13 40  4 26
#  50 37 45 30 46 34]
# GPuxgent(0.75)
# eauigent(0.6388888888888888)
# Gyhigeht(0.5)
# plYigeEt(0.625)
# Gtuwgent(0.75)
# GlmEgent(0.875)
# eluvgent(0.7638888888888888)
# Bluigent(0.875)
# Gtuxgent(0.75)
# vluigZnt(0.75)
# GyuCgedt(0.625)
# GyuJgent(0.75)
# GluCgenK(0.75)
# Gluwgent(0.875)
# GyuJgent(0.75)
# GyuJgent(0.75)
# GyuJgedt(0.625)
# GluxgenX(0.75)
# GyhEgent(0.625)
# GluuFent(0.75)
# GTQigent(0.625)
# GyuJgent(0.75)
# GluCgent(0.875)
# uluvgent(0.75)
# GluJgent(0.875)
# vlYigent(0.625)
# Gluvgeht(0.75)
# Gyuxgent(0.75)
# plYigent(0.625)
# GluJgent(0.875)
# [112, 108, 89, 105, 103, 101, 69, 116]
# 1
# [71, 121, 117, 67, 103, 101, 100, 116]
# 7
# [71, 121, 117, 74, 103, 101, 110, 116]
# 0
# [71, 121, 104, 69, 103, 101, 110, 116]
# 4
# [71, 84, 81, 105, 103, 101, 110, 116]
# 4
# [71, 108, 117, 67, 103, 101, 110, 116]
# 6
# [117, 108, 117, 118, 103, 101, 110, 116]
# 3
# [71, 108, 117, 118, 103, 101, 104, 116]
# 3
# [71, 108, 117, 74, 103, 101, 110, 116]
# 3
# 染色体数65
# 染色体数65
# ルーレット選択[18 63 14 11 31 13 54  6 62 25 28 37 22 39 15 55 40 10  5 33 16 34 60 35
#   8 47 20 64 42 57]
# GyhELent(0.625)
# GluDgeht(0.75)
# GyuJgent(0.75)
# hyuJgent(0.75)
# eauigent(0.6388888888888888)
# Gluwgent(0.875)
# GyuJgedt(0.625)
# eluvgent(0.7638888888888888)
# ululgent(0.75)
# vlYigent(0.625)
# plYigent(0.625)
# Gtuwgent(0.75)
# GluCgeFt(0.875)
# GlmEgent(0.75)
# GyuJgent(0.75)
# GyuJgent(0.75)
# GyuJgent(0.75)
# GyuCgedy(0.625)
# GlmEgent(0.875)
# GluuFent(0.75)
# GyuJgedt(0.625)
# GPuxgent(0.75)
# GTQiaent(0.5)
# vlYigent(0.625)
# Gtuxgent(0.75)
# Gyuigent(0.75)
# GTQiaent(0.625)
# Gluhgent(0.875)
# Gyuigedt(0.625)
# GyuCgedy(0.5)
# [71, 121, 117, 74, 103, 101, 110, 116]
# 5
# [71, 121, 117, 74, 103, 101, 100, 116]
# 4
# [71, 116, 117, 119, 103, 101, 110, 116]
# 3
# [71, 108, 109, 69, 103, 101, 110, 116]
# 2
# [71, 121, 117, 74, 103, 101, 110, 116]
# 5
# [71, 121, 117, 74, 103, 101, 100, 116]
# 1
# [71, 80, 117, 120, 103, 101, 110, 116]
# 2
# [118, 108, 89, 105, 103, 101, 110, 116]
# 4
# [71, 121, 117, 105, 103, 101, 110, 116]
# 5
# [71, 84, 81, 105, 97, 101, 110, 116]
# 4
# 染色体数66
# 染色体数66
# ルーレット選択[31 20 24 22 36 43 50 45 40 23 21 62 37 17 16 49 58 56 39  1 10 64 18 47
#  48 54 55 42 30 15]
# Gluwgent(0.875)
# GDuJgedt(0.625)
# Gtuxgent(0.75)
# GTQiCent(0.5)
# pluJgent(0.75)
# vlYigent(0.625)
# GluDLent(0.75)
# vlYiaent(0.5)
# GlmEgent(0.75)
# vlYilent(0.625)
# GPvxgent(0.75)
# GPvxgent(0.625)
# hyYigent(0.5)
# GyuCgedy(0.625)
# GyuJgXnt(0.75)
# GyuJgent(0.75)
# Gtuagent(0.75)
# GyuJgFnt(0.625)
# GyuCgedy(0.5)
# GluDgeht(0.75)
# plYigent(0.625)
# GyuigYnt(0.625)
# GlmEgent(0.875)
# Gluugent(0.875)
# ululgent(0.75)
# Gyuvgent(0.75)
# eluJgent(0.7638888888888888)
# GyuJgent(0.75)
# eauigent(0.6388888888888888)
# GyuJgent(0.75)
# [118, 108, 89, 105, 103, 101, 110, 116]
# 1
# [71, 121, 117, 74, 103, 101, 110, 116]
# 5
# [71, 121, 117, 74, 103, 70, 110, 116]
# 7
# 染色体数59
# 染色体数59
# ルーレット選択[26 56 17 58 49 33 48 55 38 42 15 19 51 52 20 36 25 11  9 23 39 46 37 21
#  54 28  0 40 30 24]
# eluJgent(0.7638888888888888)
# vGYigent(0.5138888888888888)
# GyuJgFnV(0.625)
# GyuJgFnV(0.5)
# GPvxgent(0.625)
# GluEgeht(0.75)
# GyuJgent(0.75)
# GyuJgent(0.75)
# GPuCgedy(0.5)
# GlYigent(0.75)
# GyuJgnnt(0.75)
# GluDgeht(0.75)
# GyuiCent(0.625)
# uluigYnt(0.625)
# plYigent(0.625)
# Gtuagedt(0.625)
# Gyuvgent(0.75)
# GPvxgent(0.625)
# vlYilent(0.625)
# Gluugent(0.875)
# Gyvxgent(0.625)
# Gauigent(0.75)
# GDuJgent(0.75)
# GyuigYnt(0.625)
# Gtuxgent(0.75)
# eauigent(0.6388888888888888)
# Gluwgent(0.875)
# Gluugent(0.875)
# GlYwgent(0.75)
# ululgent(0.75)
# [118, 71, 89, 105, 103, 101, 110, 116]
# 6
# [71, 108, 117, 69, 103, 101, 104, 116]
# 0
# [71, 121, 117, 74, 103, 101, 110, 116]
# 7
# [71, 108, 89, 105, 103, 101, 110, 116]
# 3
# [71, 121, 117, 105, 67, 101, 110, 116]
# 2
# [71, 121, 117, 118, 103, 101, 110, 116]
# 4
# [71, 108, 117, 117, 103, 101, 110, 116]
# 4
# [71, 68, 117, 74, 103, 101, 110, 116]
# 4
# 染色体数62
# 染色体数62
# ルーレット選択[14  3 59 40 13  7 30  0  9 41 38 20 57 61 22 36  6  2 27 52 33 23 45 60
#  25 11 56 24 26 12]
# plYigent(0.625)
# GyuJgFnV(0.5)
# GyuvJent(0.625)
# GyuJgent(0.75)
# uluigYnt(0.625)
# GyuJgenu(0.75)
# vluilent(0.625)
# eluJgent(0.7638888888888888)
# GlYQgent(0.75)
# GPvxgnnt(0.5)
# GyuiCent(0.625)
# Gyvxgent(0.625)
# GlYQgent(0.75)
# GDuJeent(0.6388888888888888)
# GDuJeent(0.75)
# GlYwgent(0.75)
# GyuJgent(0.75)
# GyuJgFnV(0.625)
# Gluugent(0.875)
# Gyuigent(0.75)
# Gtuxgeht(0.625)
# GyuigYnt(0.625)
# GyuJgent(0.75)
# Gluuuent(0.75)
# eauigent(0.6388888888888888)
# GluDgeht(0.75)
# GyuJgenu(0.625)
# Gtuxgent(0.75)
# Gluwgent(0.875)
# GyGiCent(0.625)
# [71, 121, 117, 74, 103, 101, 110, 117]
# 1
# [101, 108, 117, 74, 103, 101, 110, 116]
# 5
# [71, 108, 89, 81, 103, 101, 110, 116]
# 2
# [71, 121, 118, 120, 103, 101, 110, 116]
# 7
# [71, 121, 117, 74, 103, 70, 110, 86]
# 0
# [71, 108, 117, 117, 103, 101, 110, 116]
# 3
# [71, 121, 117, 105, 103, 89, 110, 116]
# 5
# [71, 121, 117, 74, 103, 101, 110, 116]
# 4
# [71, 108, 117, 117, 117, 101, 110, 116]
# 6
# [101, 97, 117, 105, 103, 101, 110, 116]
# 5
# [71, 116, 117, 120, 103, 101, 110, 116]
# 7
# [71, 121, 71, 105, 67, 101, 110, 116]
# 7
# 染色体数68
# 染色体数68
# ルーレット選択[22 46 58 20 30 12  4 33 15 34 19 31 61 52 16 38 40 64 45 39 42 24  8 13
#  25  3 49 23 43 21]
# GyuJnent(0.75)
# GyGJgenu(0.5138888888888888)
# GlaQgent(0.75)
# Gtuxgeht(0.625)
# Gluuuent(0.75)
# GlaQgent(0.75)
# uluigYnt(0.625)
# Gluwgnnt(0.75)
# GlYwgent(0.75)
# GluJgFnt(0.75)
# Gyuigent(0.75)
# eauigent(0.6388888888888888)
# Glujgent(0.875)
# vluilent(0.625)
# GyuJgent(0.75)
# GyuJgent(0.75)
# GDuJeent(0.6388888888888888)
# GluuueUt(0.625)
# eluJgYnt(0.6388888888888888)
# GlYwgent(0.75)
# Gluigent(0.875)
# eauigSnt(0.6388888888888888)
# GlaQgent(0.75)
# GDuJeent(0.6388888888888888)
# GluDgeht(0.75)
# GyuJgent(0.75)
# GluDgeht(0.75)
# GluuueUt(0.75)
# GyuugYnt(0.625)
# Gyuigfnt(0.625)
# [71, 108, 117, 117, 117, 101, 110, 116]
# 5
# [117, 108, 117, 105, 103, 89, 110, 116]
# 5
# [71, 108, 89, 119, 103, 101, 110, 116]
# 0
# [71, 121, 117, 105, 103, 101, 110, 116]
# 4
# [71, 108, 117, 117, 117, 101, 85, 116]
# 0
# [71, 121, 117, 105, 103, 102, 110, 116]
# 1
# 染色体数60
# 染色体数60
# ルーレット選択[35  5 29 10 14 43 48 55  6 17 13 19 54  3 20 11 53 18 44 45 36 37 56 41
#  26 58 33 52 34 57]
# Gtuxueht(0.5)
# GlaQgent(0.75)
# Gduigfnt(0.625)
# Gyuixent(0.75)
# GyuJgent(0.75)
# GluugYnt(0.75)
# Gluigent(0.875)
# uluigant(0.625)
# uluigant(0.625)
# nluuueUt(0.625)
# vluilent(0.625)
# GlYwgent(0.75)
# GluuuPnt(0.625)
# Gtuxgeht(0.625)
# Gluigent(0.875)
# eauigent(0.6388888888888888)
# GyuJgent(0.75)
# eluJgYnt(0.6388888888888888)
# eyuigent(0.6388888888888888)
# Gauigent(0.75)
# eluJgYnt(0.6388888888888888)
# GlaQgent(0.75)
# MlYwgent(0.625)
# GluJeent(0.7638888888888888)
# GluDgeht(0.75)
# nluuueUt(0.5138888888888888)
# Gyuigent(0.75)
# GlYwgent(0.75)
# Gluugent(0.875)
# Gyuixent(0.625)
# [117, 108, 117, 105, 103, 97, 110, 116]
# 2
# [101, 108, 117, 74, 103, 89, 110, 116]
# 3
# [101, 108, 117, 74, 103, 89, 110, 116]
# 6
# [77, 108, 89, 119, 103, 101, 110, 116]
# 1
# [71, 108, 117, 68, 103, 101, 104, 116]
# 1
# 染色体数65
# 染色体数65
# ルーレット選択[21 15 27 28 53 14  5 36  1 38 35 48  0 30 19 56 39 31  7 11 44 26 50 29
#  55  9 43 61 34 57]
# GlaQgent(0.75)
# eauigent(0.6388888888888888)
# GlYwgent(0.75)
# Gluugent(0.875)
# Gyuxgeht(0.625)
# Gluigent(0.875)
# GluugYnt(0.75)
# nyuigent(0.625)
# GlaQgent(0.75)
# uluigant(0.625)
# GyuJgent(0.75)
# Gluigfnt(0.75)
# Gtuxueht(0.5)
# GlYwgent(0.75)
# Gauigent(0.75)
# uluixent(0.625)
# GluuuPnt(0.625)
# vluilent(0.625)
# ulvigant(0.625)
# GlYwgent(0.75)
# Mluwgent(0.75)
# Gyuigent(0.75)
# GlaQgeht(0.625)
# Gyuixent(0.625)
# Gluixent(0.75)
# nluuueUt(0.625)
# eauigent(0.6388888888888888)
# elungYnt(0.6388888888888888)
# GlaQgent(0.75)
# Gyuigant(0.625)
# [71, 108, 89, 119, 103, 101, 110, 116]
# 5
# [71, 121, 117, 120, 103, 101, 104, 116]
# 2
# [71, 108, 117, 117, 103, 89, 110, 116]
# 4
# [117, 108, 118, 105, 103, 97, 110, 116]
# 3
# 染色体数60
# 染色体数60
# ルーレット選択[31 26 37  4 12 24 42  8 41 25  0 43 18 40 38 51 16 54 29 55 36 48 22 21
#  14 49 33 56 45 13]
# Glaugent(0.7638888888888888)
# eauigent(0.6388888888888888)
# Gyuigant(0.625)
# Gyqxgeht(0.625)
# Gtuxueht(0.5)
# Gluixent(0.75)
# Myuixent(0.5)
# GlaQgent(0.75)
# Gluigent(0.875)
# nluuueUt(0.625)
# GlaQgent(0.75)
# Gluwgent(0.875)
# ulvQgant(0.625)
# GluuuPnt(0.625)
# Gyuigent(0.75)
# ulaQgant(0.5138888888888888)
# GluuuPnt(0.625)
# ulvngYnt(0.5138888888888888)
# Gyuigant(0.625)
# eluigant(0.6388888888888888)
# eauigent(0.6388888888888888)
# GlaQleht(0.5)
# GlaQgeht(0.625)
# Gyuigent(0.75)
# Gauigent(0.75)
# vluigent(0.75)
# GlYwgent(0.75)
# GlYwgKnt(0.625)
# eauxueht(0.3888888888888889)
# GlYwgent(0.75)
# [71, 108, 117, 105, 120, 101, 110, 116]
# 0
# [71, 108, 97, 81, 103, 101, 110, 116]
# 1
# [117, 108, 118, 81, 103, 97, 110, 116]
# 5
# [71, 121, 117, 105, 103, 97, 110, 116]
# 6
# [101, 108, 117, 105, 103, 97, 110, 116]
# 0
# 染色体数57
# 染色体数57
# ルーレット選択[ 1 20 38 16 11 27 14 39  7 44  6 51 17 50 52 33 54  5 34 26 23  3 49 53
#  40 37 41 30 48  0]
# eauigent(0.6388888888888888)
# eauigent(0.6388888888888888)
# Gtuxueht(0.5)
# GluuuPnt(0.625)
# Gluwgent(0.875)
# GlYwgKnt(0.625)
# Gyuigent(0.75)
# vluigent(0.75)
# GlaQgent(0.75)
# Glaugent(0.7638888888888888)
# Myuixent(0.5)
# Gluigent(0.875)
# ulvngYnt(0.5138888888888888)
# GlYwgKnt(0.625)
# pluixent(0.625)
# Gluwgent(0.875)
# ulvQgUnt(0.5138888888888888)
# pluixent(0.75)
# Gyuigant(0.625)
# GlYwgent(0.75)
# Gyuigent(0.75)
# Gyqxgeht(0.625)
# Gluugent(0.875)
# GnaQgent(0.625)
# ulaQgaht(0.3888888888888889)
# ulvQgant(0.5138888888888888)
# eauxuent(0.5138888888888888)
# Gyqxgent(0.625)
# GyuiuPnt(0.5)
# Glaugent(0.7638888888888888)
# [101, 97, 117, 105, 103, 101, 110, 116]
# 0
# [101, 97, 117, 105, 103, 101, 110, 116]
# 7
# [71, 116, 117, 120, 117, 101, 104, 116]
# 4
# [71, 108, 97, 117, 103, 101, 110, 116]
# 5
# [117, 108, 118, 81, 103, 85, 110, 116]
# 1
# [71, 108, 117, 117, 103, 101, 110, 116]
# 2
# [117, 108, 97, 81, 103, 97, 104, 116]
# 6
# [101, 97, 117, 120, 117, 101, 110, 116]
# 7
# [71, 121, 113, 120, 103, 101, 110, 116]
# 6
# [71, 121, 117, 105, 117, 80, 110, 116]
# 1
# 染色体数62
# 染色体数62
# ルーレット選択[51 20 35 42 25 55  3 10 54 27 19 57 48 52 23 21  8 30 32  4 11 26 50 18
#   6 41 43 59 40 44]
# Gluigent(0.875)
# Gyuigent(0.75)
# eauigent(0.6388888888888888)
# elYwgent(0.6388888888888888)
# ulvQgant(0.5138888888888888)
# Glaugpnt(0.6388888888888888)
# GluuuPnt(0.625)
# Myuixent(0.5)
# Gtuxmeht(0.5)
# Gyqxgebt(0.625)
# GlYwgent(0.75)
# Glrugent(0.7638888888888888)
# Gluxgent(0.875)
# Lauigent(0.625)
# GnaQgent(0.625)
# Gyqxgeht(0.625)
# GlaQgent(0.75)
# GluiuPnt(0.625)
# Gyuwgent(0.75)
# Gluwgent(0.875)
# Gluigent(0.875)
# eauxuenv(0.5138888888888888)
# plauxent(0.5138888888888888)
# Gyuigant(0.625)
# Gyuigent(0.75)
# Myuugent(0.625)
# Gauigent(0.75)
# eauxuenv(0.3888888888888889)
# Glaixent(0.625)
# vluigYnt(0.625)
# [71, 121, 117, 105, 103, 101, 110, 116]
# 5
# [71, 108, 117, 117, 117, 80, 110, 116]
# 7
# [77, 121, 117, 105, 120, 101, 110, 116]
# 0
# [71, 121, 117, 119, 103, 101, 110, 116]
# 1
# [118, 108, 117, 105, 103, 89, 110, 116]
# 0
# 染色体数61
# 染色体数61
# ルーレット選択[38  7 17 45 50 31 37 47  1 39 22 56  8 20 19 26  6 24 12 60 25  9 49  5
#  14 33 21 29 58  3]
# Gluwgent(0.875)
# eyuixent(0.5)
# GluiuPnt(0.625)
# Gauigent(0.75)
# Gluigent(0.875)
# Gyuigant(0.625)
# Gyqxgeht(0.5)
# Glaxgebt(0.625)
# Gyuigknt(0.75)
# Glaixent(0.625)
# plauxent(0.5138888888888888)
# Gyuigknt(0.625)
# Gtuxmeht(0.5)
# Gluigent(0.875)
# Gluwgent(0.875)
# Gauigent(0.75)
# GluuuPnq(0.625)
# Gyuigent(0.75)
# Gluxgent(0.875)
# pluigYnt(0.625)
# Myuugent(0.625)
# Gyqxgebt(0.625)
# Glrugent(0.7638888888888888)
# Glaugpnt(0.6388888888888888)
# GnaQgent(0.625)
# elYwgent(0.6388888888888888)
# eauxuenv(0.5138888888888888)
# pluigYnt(0.625)
# eyuixent(0.5138888888888888)
# elYwgent(0.6388888888888888)
# [101, 121, 117, 105, 120, 101, 110, 116]
# 7
# [71, 108, 97, 120, 103, 101, 98, 116]
# 4
# [71, 121, 117, 105, 103, 107, 110, 116]
# 7
# [71, 116, 117, 120, 109, 101, 104, 116]
# 7
# [77, 121, 117, 117, 103, 101, 110, 116]
# 5
# [71, 108, 97, 117, 103, 112, 110, 116]
# 2
# 染色体数60
# 染色体数60
# ルーレット選択[50 22 38 13 12 48 16 40 11 47  9 39 23 14  0 42 17  5  3 37 24 28 27 35
#  54 41 21 31 32 56]
# eauxuenv(0.3888888888888889)
# Glrugent(0.7638888888888888)
# eyuigent(0.6388888888888888)
# Gluigent(0.875)
# Gtuxmehe(0.5)
# GluigYnt(0.75)
# GluuuPnq(0.625)
# Gluigent(0.875)
# GyuigknJ(0.625)
# Gyuugent(0.75)
# Glaixent(0.625)
# elYwxent(0.5138888888888888)
# Glzugpnt(0.6388888888888888)
# Gluwgent(0.875)
# Gluwgent(0.875)
# Glaugpnt(0.6388888888888888)
# Gyuigent(0.75)
# Gyuigant(0.625)
# Gauigent(0.75)
# GnaQgent(0.625)
# GnaQgent(0.625)
# eyuixenn(0.5138888888888888)
# pluigYnt(0.625)
# GyqigYnt(0.5)
# eyuixenn(0.3888888888888889)
# Gauwgent(0.75)
# Gyqxgebt(0.625)
# Gluxmeht(0.625)
# Gyuxgebt(0.625)
# GyuigknJ(0.5)
# [71, 108, 117, 105, 103, 89, 110, 116]
# 4
# [71, 121, 117, 105, 103, 107, 110, 74]
# 2
# [101, 108, 89, 119, 120, 101, 110, 116]
# 6
# [71, 108, 122, 117, 103, 112, 110, 116]
# 0
# [71, 110, 97, 81, 103, 101, 110, 116]
# 4
# [71, 110, 97, 81, 103, 101, 110, 116]
# 2
# [101, 121, 117, 105, 120, 101, 110, 110]
# 2
# [71, 121, 113, 105, 103, 89, 110, 116]
# 3
# [71, 121, 113, 120, 103, 101, 98, 116]
# 2
# 染色体数65
# 染色体数65
# ルーレット選択[47 52  1  4 40 38 43 31 37 54 10 22 57 49 53 46 19 17 25 32 16  3  0 44
#  64 13 36 20 30 28]
# Gluwmeht(0.625)
# GnaQgent(0.625)
# Glrugent(0.7638888888888888)
# Gtuxmehe(0.5)
# Gluwgenq(0.75)
# Glaigent(0.75)
# Glrugent(0.7638888888888888)
# Glzugpnt(0.6388888888888888)
# GyuigknJ(0.5)
# Gyuugebt(0.625)
# Glaixent(0.625)
# pluigYnt(0.625)
# GygigknJ(0.375)
# Gluugpnt(0.75)
# Gluigent(0.875)
# Gluxgent(0.875)
# GnaQTent(0.625)
# Gyuigant(0.625)
# Gauwgent(0.75)
# eluigent(0.7638888888888888)
# Gyuigent(0.75)
# Gluigent(0.875)
# eauxuenv(0.3888888888888889)
# pluigant(0.625)
# Gyixgebt(0.5)
# Gluwgent(0.875)
# Gyuigent(0.75)
# GnoQgent(0.625)
# GluigYnt(0.75)
# Gyuxgebt(0.625)
# [71, 108, 97, 105, 103, 101, 110, 116]
# 5
# [71, 108, 97, 105, 120, 101, 110, 116]
# 3
# [71, 108, 117, 120, 103, 101, 110, 116]
# 2
# [71, 110, 97, 81, 84, 101, 110, 116]
# 2
# [71, 97, 117, 119, 103, 101, 110, 116]
# 0
# [71, 121, 105, 120, 103, 101, 98, 116]
# 2
# [71, 121, 117, 105, 103, 101, 110, 116]
# 0
# [71, 110, 111, 81, 103, 101, 110, 116]
# 5
# [71, 121, 117, 120, 103, 101, 98, 116]
# 1
# 染色体数65
# 染色体数65
# ルーレット選択[22  9 59 19 26 14 13 58 46 55 25 47 43 27 44 18 23 35  6 54 12 28 24 48
#  10 62 37 60 45 21]
# eauxuenv(0.3888888888888889)
# Gyuugebt(0.625)
# GnaQTent(0.5)
# eluigent(0.7638888888888888)
# kyuigent(0.75)
# Gluigent(0.875)
# Gluugpnt(0.75)
# Gltxgent(0.75)
# eluigenJ(0.6388888888888888)
# Gluugpnt(0.75)
# Gluwgent(0.875)
# Gyuigknt(0.625)
# pluigant(0.625)
# GnoQgznt(0.625)
# GloQxent(0.625)
# yauwgent(0.75)
# pluigant(0.625)
# GluigYnt(0.75)
# Glrugent(0.7638888888888888)
# Gauwgent(0.75)
# GygigknJ(0.375)
# GluigYnt(0.75)
# Gyaxgebt(0.5)
# Gnrugent(0.6388888888888888)
# Glabxent(0.625)
# kyuigent(0.625)
# GluQTent(0.75)
# yauwgent(0.625)
# Gnaigent(0.625)
# Gluigent(0.875)
# [71, 110, 97, 81, 84, 101, 110, 116]
# 6
# [71, 108, 117, 105, 103, 101, 110, 116]
# 1
# [71, 108, 117, 119, 103, 101, 110, 116]
# 5
# [71, 121, 117, 105, 103, 107, 110, 116]
# 3
# [121, 97, 117, 119, 103, 101, 110, 116]
# 6
# [71, 108, 114, 117, 103, 101, 110, 116]
# 5
# [71, 108, 117, 105, 103, 89, 110, 116]
# 5
# [71, 110, 114, 117, 103, 101, 110, 116]
# 3
# [71, 108, 117, 81, 84, 101, 110, 116]
# 2
# [71, 110, 97, 105, 103, 101, 110, 116]
# 4
# [71, 108, 117, 105, 103, 101, 110, 116]
# 7
# 染色体数67
# 染色体数67
# ルーレット選択[25 34 66 57 56 40 60  0  4 65 12  6 18 20 30 64 41 19 59 15 24 36 54 39
#   5 47 48  8 21  2]
# kyuigent(0.625)
# Gluugent(0.875)
# GluigenI(0.75)
# Guuigent(0.75)
# GnaQTeAt(0.3888888888888889)
# Gluigent(0.875)
# yauwgeat(0.5)
# eauxuenv(0.3888888888888889)
# kyuigent(0.75)
# Gnaicent(0.5)
# pluigant(0.625)
# Gluugpnt(0.75)
# Glrugjnt(0.7638888888888888)
# GygigknJ(0.375)
# Glrugent(0.7638888888888888)
# GlGQTent(0.625)
# GloQxent(0.625)
# Gauwgent(0.75)
# GyuBgknt(0.625)
# yauwgeat(0.75)
# Glabxent(0.625)
# pltxgent(0.625)
# yauwgenv(0.5)
# GluigYnt(0.75)
# Guuigent(0.875)
# kyuigznt(0.5)
# GluQTent(0.75)
# eluigenJ(0.6388888888888888)
# Gluigent(0.75)
# GnaQTeAt(0.5)
# [71, 108, 117, 117, 103, 101, 110, 116]
# 5
# [71, 108, 117, 105, 103, 101, 110, 73]
# 5
# [71, 108, 117, 105, 103, 101, 110, 116]
# 4
# [71, 110, 97, 105, 99, 101, 110, 116]
# 0
# [121, 97, 117, 119, 103, 101, 110, 118]
# 1
# [71, 108, 117, 105, 103, 89, 110, 116]
# 6
# [101, 108, 117, 105, 103, 101, 110, 74]
# 5
# [71, 108, 117, 105, 103, 101, 110, 116]
# 6
# [71, 110, 97, 81, 84, 101, 65, 116]
# 4
# 染色体数65
# 染色体数65
# ルーレット選択[41  8 45  2 34 29 38 42  6 54 16 26 61 12 50 21 10 20 18 27 62  5 51  3
#  37 11 17 23 59 36]
# Glabxent(0.625)
# kyuigent(0.75)
# GluiTent(0.75)
# GluigKnI(0.75)
# Glrugent(0.7638888888888888)
# GnaQceAt(0.5)
# yauwgeat(0.5)
# kyuigznt(0.5)
# yauwgeat(0.5)
# Gluigent(0.875)
# GloQxent(0.625)
# GluQTent(0.75)
# GluigYPt(0.625)
# Glrugjnt(0.7638888888888888)
# GloQxent(0.625)
# pltxgent(0.625)
# pluigant(0.625)
# Glabxent(0.625)
# GyuBgknt(0.625)
# eluigRnJ(0.6388888888888888)
# eluigRnJ(0.5138888888888888)
# Gluisent(0.875)
# pltxgent(0.625)
# Guuigent(0.75)
# Glrugjnt(0.6388888888888888)
# Gluugpnt(0.75)
# Gauwgent(0.75)
# GluigYPt(0.75)
# znaicent(0.375)
# GluigYnt(0.75)
# [71, 108, 97, 98, 120, 101, 110, 116]
# 2
# [71, 108, 114, 117, 103, 101, 110, 116]
# 3
# [107, 121, 117, 105, 103, 122, 110, 116]
# 2
# [71, 108, 117, 81, 84, 101, 110, 116]
# 7
# [101, 108, 117, 105, 103, 82, 110, 74]
# 2
# [71, 108, 117, 105, 103, 89, 80, 116]
# 3
# 染色体数56
# 染色体数56
# ルーレット選択[ 4 15 41  9 14 22 48 52 40 23 49 25 34 21 44  0  1 43  2 51 53 46 42  7
#  10 11 12 35  3 24]
# Glrtgent(0.7638888888888888)
# pltxgent(0.625)
# Gauwgjnt(0.625)
# Gluigent(0.875)
# GloQxent(0.625)
# pltxgent(0.625)
# GluisePt(0.625)
# kyvigznt(0.375)
# ylrugeat(0.5138888888888888)
# Guuigent(0.75)
# GluigYnt(0.75)
# Gluugpnt(0.75)
# GloQgpnt(0.625)
# Gluisent(0.875)
# kyuigznt(0.5)
# Glkbxent(0.625)
# kyuigent(0.75)
# eltxgRnJ(0.4027777777777778)
# GluiTent(0.75)
# Glrtgent(0.75)
# GluQTeny(0.625)
# kyuigknt(0.5)
# pluigent(0.75)
# kyvigznt(0.5)
# GloQxent(0.625)
# GluQTeny(0.75)
# GluHgYPt(0.625)
# Gluuxent(0.75)
# GluigKnI(0.75)
# Glrugjnt(0.6388888888888888)
# [71, 108, 111, 81, 120, 101, 110, 116]
# 5
# [121, 108, 114, 117, 103, 101, 97, 116]
# 0
# [71, 108, 117, 105, 103, 89, 110, 116]
# 7
# [71, 108, 117, 117, 103, 112, 110, 116]
# 1
# [107, 121, 117, 105, 103, 107, 110, 116]
# 3
# [71, 108, 117, 81, 84, 101, 110, 121]
# 5
# 染色体数56
# 染色体数56
# ルーレット選択[46 47 27  6  2 28 52 20 41 32 26 35 25 54 31 53 50  3 49  0 12 13 44 15
#  37 17 45  4 51 38]
# Gluiseny(0.625)
# GluQTent(0.75)
# Gluuxent(0.75)
# GluisePt(0.625)
# Gauwgjnt(0.625)
# GluigKnI(0.75)
# GluigYny(0.625)
# GluQTgny(0.625)
# pluwgjnt(0.625)
# Gloigent(0.75)
# GluHgYPt(0.625)
# GloQgpnt(0.625)
# GluQTgny(0.75)
# kyuAgknt(0.5)
# Glkbxent(0.625)
# GLuugpnt(0.625)
# GloQxwnt(0.5)
# Gluigent(0.875)
# Gyuigznt(0.625)
# Glrtgent(0.7638888888888888)
# GloQgpnt(0.625)
# Gluisent(0.875)
# GluHgYnt(0.75)
# Glkbxent(0.625)
# ylrugRnJ(0.3888888888888889)
# eltxgRnJ(0.4027777777777778)
# GluigePt(0.75)
# GloQxwnt(0.625)
# rlrugeat(0.5138888888888888)
# Glrtxent(0.625)
# [71, 108, 117, 117, 120, 101, 110, 116]
# 6
# [71, 97, 117, 119, 103, 106, 110, 116]
# 1
# [112, 108, 117, 119, 103, 106, 110, 116]
# 2
# [71, 108, 111, 81, 103, 112, 110, 116]
# 0
# [71, 108, 117, 81, 84, 103, 110, 121]
# 6
# [71, 108, 111, 81, 120, 119, 110, 116]
# 4
# [71, 108, 117, 72, 103, 89, 110, 116]
# 3
# [101, 108, 116, 120, 103, 82, 110, 74]
# 6
# 染色体数66
# 染色体数66
# ルーレット選択[13 64 43 60 45 39 27 55 42 16 33 40  1 11 56 22 48 34 61 14  4 44 62 21
#  12 26 24 54  0 51]
# kyuAgknt(0.5)
# GluFgYnt(0.75)
# Gluigznt(0.75)
# plGwgjnt(0.5138888888888888)
# Glrtxent(0.625)
# GluigYnI(0.625)
# GloQFwnt(0.625)
# eltxgRnJ(0.4027777777777778)
# Gykbxent(0.5)
# GloQFwnt(0.5)
# Glowgent(0.75)
# GluQseny(0.625)
# GluQTent(0.75)
# nloQgpnt(0.625)
# ylrugpnJ(0.3888888888888889)
# GluFgYnt(0.75)
# GluQseny(0.625)
# rlrisePt(0.375)
# nloQgpnt(0.5)
# Glkbxent(0.625)
# Gcuwgjnt(0.625)
# pluwgjnt(0.625)
# GluQTgny(0.5138888888888888)
# Gluisent(0.875)
# GluQTgny(0.75)
# GluigePt(0.75)
# ylrugRnJ(0.3888888888888889)
# GloQgpnt(0.625)
# Gluiseny(0.625)
# GloQgYnt(0.625)
# [71, 108, 117, 105, 103, 89, 110, 73]
# 6
# [71, 108, 111, 81, 70, 119, 110, 116]
# 7
# [71, 108, 117, 81, 115, 101, 110, 121]
# 5
# [71, 108, 117, 70, 103, 89, 110, 116]
# 6
# [71, 108, 117, 105, 115, 101, 110, 121]
# 4
# 染色体数59
# 染色体数59
# ルーレット選択[52  2 37 40 30 19 55 17 46 12 11 27 50 24 20 16  9 21 25 53 39  5 32  3
#  15 31 49  4 57 56]
# Gluigpny(0.625)
# Gluigznt(0.75)
# GltxgRnJ(0.5138888888888888)
# kyubxent(0.5)
# Gcuwgjnt(0.625)
# Glkbxent(0.625)
# GloQFwnB(0.375)
# rlrisePt(0.375)
# GlGwgent(0.75)
# GluQTent(0.75)
# GluQsBny(0.625)
# GloQgpnt(0.625)
# GluQgYny(0.625)
# GluQTgny(0.75)
# Gcuwgjnt(0.625)
# GluQseny(0.625)
# GloQFwnB(0.5)
# pluwgjnt(0.625)
# GluigePt(0.75)
# nloQsent(0.5)
# GloQgYnt(0.625)
# GluigYcI(0.625)
# nloQgpnt(0.5)
# plGwgjnt(0.5138888888888888)
# GluFgYNt(0.75)
# GloQgpnt(0.625)
# Glrugpnt(0.6388888888888888)
# Glrtxent(0.625)
# GluFgYNt(0.625)
# GluQsBny(0.5)
# [71, 108, 116, 120, 103, 82, 110, 74]
# 0
# [71, 108, 107, 98, 120, 101, 110, 116]
# 7
# [114, 108, 114, 105, 115, 101, 80, 116]
# 1
# [71, 108, 71, 119, 103, 101, 110, 116]
# 2
# [71, 108, 117, 81, 84, 101, 110, 116]
# 7
# [112, 108, 117, 119, 103, 106, 110, 116]
# 6
# [71, 108, 117, 105, 103, 89, 99, 73]
# 6
# [110, 108, 111, 81, 103, 112, 110, 116]
# 6
# [112, 108, 71, 119, 103, 106, 110, 116]
# 1
# [71, 108, 114, 116, 120, 101, 110, 116]
# 3
# [71, 108, 117, 81, 115, 66, 110, 121]
# 1
# 染色体数63
# 染色体数63
# ルーレット選択[59 28  1 50  0 47 27 38 21 30 34 53 58 49  8 26 12 32  4 24 31  2 41  9
#  11 46 44 18 33  7]
# nloQgpNt(0.3888888888888889)
# GluFgYNt(0.625)
# Gluigznt(0.75)
# GloQgent(0.75)
# Gluigpny(0.625)
# ploQgYnt(0.5)
# GlrOxent(0.625)
# Gluwgjnt(0.75)
# GluigYqI(0.625)
# GluQsBny(0.5)
# GluQFwnB(0.5)
# GlkbxenE(0.5)
# GluigYqI(0.5)
# GloFgpnt(0.625)
# Glqwgent(0.75)
# Glrugpnt(0.6388888888888888)
# GluQgYny(0.625)
# Gcrigjnt(0.5)
# Gcuwgjnt(0.625)
# GluFgYNt(0.75)
# GluQgYny(0.625)
# BltxgRnJ(0.5138888888888888)
# Gluigpnt(0.75)
# GluQTenb(0.75)
# GloQgpnt(0.625)
# Gluwgjnt(0.75)
# GltwgRnJ(0.5138888888888888)
# GluigePt(0.75)
# rluwsePt(0.5)
# rTrisePt(0.375)
# [71, 108, 117, 70, 103, 89, 78, 116]
# 0
# [71, 108, 114, 117, 103, 112, 110, 116]
# 1
# [71, 108, 117, 81, 84, 101, 110, 98]
# 3
# 染色体数59
# 染色体数59
# ルーレット選択[19 48 33  3 41 40 12 44  1 51 28 43 22 36 55 10 15  7 42 34 32 31 18 47
#  27 21 56 54 13  9]
# aluFgYNt(0.75)
# GluQgYny(0.625)
# Gltwgjnt(0.625)
# GloQgent(0.75)
# GluFgYNt(0.625)
# GluigYqI(0.5)
# GluigYqI(0.5)
# GlrOgYnt(0.625)
# aluFgYNt(0.625)
# Glqwgent(0.75)
# rluwsePt(0.5)
# GloQgenE(0.625)
# Gluigpnt(0.75)
# GluigRnt(0.75)
# GluigpNt(0.625)
# GluQFwnB(0.5)
# GUrugpnt(0.6388888888888888)
# Gluwgjnt(0.75)
# Glkbxpnt(0.5)
# rluwsePt(0.5)
# GluwgRnJ(0.625)
# GluQsBny(0.5)
# Gcuwgjnt(0.625)
# GluiTenb(0.625)
# GluigePt(0.75)
# BltxgRnJ(0.5138888888888888)
# aluFgYNt(0.5)
# nloQgePt(0.5138888888888888)
# GloFgpnt(0.625)
# GluQsBny(0.5)
# [71, 108, 116, 119, 103, 106, 110, 116]
# 1
# [71, 108, 117, 81, 115, 66, 110, 121]
# 5
# 染色体数58
# 染色体数58
# ルーレット選択[13 50 31 46 56 12  5 18  2 38 10 27 37  9 26 24 34 28  1 45 55 48 23 17
#  36 25 21 57 16 22]
# GluigRnt(0.75)
# Gltwgjnt(0.625)
# Glougent(0.7638888888888888)
# rluQgePt(0.625)
# Gqtwgjnt(0.5)
# Gluigpnt(0.75)
# GluigYqI(0.5)
# Glkbxpnt(0.5)
# Gqtwgjnt(0.625)
# Gluwgpnt(0.75)
# rluwsePt(0.5)
# nloQgePt(0.5138888888888888)
# GlkbsBny(0.375)
# Glqwgent(0.75)
# aluFgYNt(0.5)
# GluigePt(0.75)
# GluQFRnJ(0.5)
# GloFgpnt(0.625)
# GluQgYny(0.625)
# GluigBny(0.625)
# Gluigpny(0.625)
# BltxgYNt(0.375)
# GluiTenb(0.625)
# Gluwgjnt(0.75)
# GluQxpnt(0.625)
# BltxgRnJ(0.5138888888888888)
# GluQsBny(0.5)
# GluQsxny(0.5)
# GUrugpnt(0.6388888888888888)
# Gcuwgjnt(0.625)
# [71, 108, 107, 98, 115, 66, 110, 121]
# 4
# [66, 108, 116, 120, 103, 89, 78, 116]
# 6
# [71, 108, 117, 119, 103, 106, 110, 116]
# 7
# [66, 108, 116, 120, 103, 82, 110, 74]
# 5
# [71, 85, 114, 117, 103, 112, 110, 116]
# 1
# [71, 99, 117, 119, 103, 106, 110, 116]
# 3
# 染色体数60
# 染色体数60
# ルーレット選択[30 23 59 15 52  9 13 49 47 53 41 50  4 12 19  3 43  6 58 14 20 39  8 25
#  21 16 11 37 48 29]
# rluwgePt(0.625)
# Gluwgjna(0.75)
# GcuCgjnt(0.625)
# GluigePt(0.75)
# GluQxpnt(0.625)
# Gluwgpnt(0.75)
# Glqwgent(0.75)
# GluigRnt(0.75)
# GluQgpnt(0.75)
# GluigBny(0.625)
# Glqwgent(0.75)
# GluisxnI(0.5)
# Gqtwgjnt(0.5)
# GlkbUBny(0.375)
# GluigBny(0.625)
# rluQgePt(0.625)
# rluQgjnt(0.625)
# GluigYqI(0.5)
# GCrugpnt(0.5138888888888888)
# aluFgYNt(0.5)
# Gluigpny(0.625)
# GluwgjPt(0.625)
# Gqtwgjnt(0.625)
# BltxggnJ(0.5138888888888888)
# BltxgYRt(0.375)
# GluQFRnJ(0.5)
# nloQgePt(0.5138888888888888)
# Gltwgjnt(0.625)
# Gluwgpnt(0.75)
# GcuCgjnt(0.625)
# [71, 108, 107, 98, 85, 66, 110, 121]
# 3
# [71, 108, 117, 119, 103, 106, 80, 116]
# 0
# [66, 108, 116, 120, 103, 103, 110, 74]
# 0
# 染色体数57
# 染色体数57
# ルーレット選択[51 52 35 10 29  8 55 17 18 28 32 27 34  5 50 23 26 42 22 38  7 43 30 37
#  33  4 44  2 16 20]
# nluCgjnt(0.625)
# GlqQgent(0.75)
# BltxgpnJ(0.3888888888888889)
# Glqwgent(0.75)
# GcuCgjnt(0.625)
# GluQgpnt(0.75)
# hluwgjPt(0.5)
# GluigYqI(0.5)
# GCrugpnt(0.5138888888888888)
# Gluwgpnt(0.75)
# GluQgpnt(0.75)
# Gltwgjnt(0.625)
# Gluwggnt(0.75)
# Gluwgpnt(0.75)
# GcoQgePt(0.5)
# RltxggnJ(0.5138888888888888)
# nloQgePt(0.5138888888888888)
# rluFgePt(0.625)
# Gqtwgjnt(0.625)
# GluigRnt(0.75)
# GluigRnt(0.75)
# aluwgYNt(0.5)
# rlubUBnt(0.5)
# GluigBny(0.625)
# Gltwgjnt(0.625)
# GluQxpnt(0.625)
# BltxgYRt(0.375)
# GcuCgjnt(0.625)
# rluQgjnt(0.625)
# Gluigpny(0.625)
# [71, 108, 113, 81, 103, 101, 110, 116]
# 3
# [71, 99, 117, 67, 103, 106, 110, 116]
# 1
# [71, 108, 116, 119, 103, 106, 110, 116]
# 2
# [71, 108, 117, 119, 103, 103, 110, 116]
# 6
# [71, 108, 117, 119, 103, 112, 110, 116]
# 7
# [71, 108, 117, 105, 103, 112, 110, 121]
# 5
# 染色体数62
# 染色体数62
# ルーレット選択[33 25  7 11 29 52 39  8 58 27 10 12 55 18  5 45 21 31 24 41 13 20 32 14
#   1  3 22 30 57 60]
# GluQgpnt(0.75)
# GluQxpnt(0.625)
# GluigYqI(0.5)
# Gltwgjnt(0.625)
# GluigNny(0.625)
# BltigYqt(0.375)
# Glqigent(0.75)
# GCrugpnt(0.5138888888888888)
# Gltwgjnt(0.625)
# GguCgjnt(0.625)
# GluQgpnt(0.75)
# GluwggQt(0.75)
# GluigRnt(0.75)
# Gqtwgjnt(0.625)
# GluQgpnt(0.75)
# GcuCgjnt(0.625)
# aluwgYNt(0.5)
# rluFgePt(0.625)
# Gltwgjnt(0.625)
# Gltwgjnt(0.625)
# GluwgpnK(0.75)
# GluigRnt(0.75)
# Gluwgpnt(0.75)
# GcoQgePt(0.5)
# Glqzgent(0.75)
# Glqwgent(0.75)
# rlubUBnt(0.5)
# GcoQgePt(0.5)
# GguCgjnt(0.625)
# GluwgpnK(0.625)
# [71, 108, 117, 81, 120, 112, 110, 116]
# 2
# [71, 108, 113, 105, 103, 101, 110, 116]
# 2
# [71, 99, 117, 67, 103, 106, 110, 116]
# 2
# [114, 108, 117, 98, 85, 66, 110, 116]
# 6
# 染色体数58
# 染色体数58
# ルーレット選択[54 24 36 18 12  7  6 46  0 29 55  5 45 15 51 28 21 22 41 20 31  3 39 48
#   1 10 30 53 25 57]
# GlZQxpnt(0.5)
# Glqzgent(0.75)
# Gluigjnt(0.75)
# Gltwgjnt(0.625)
# GluigRnt(0.75)
# GCrugpnt(0.5138888888888888)
# GlKigent(0.75)
# BltwgYNt(0.375)
# GluQgpnt(0.75)
# GluwgpnK(0.625)
# GlKigent(0.75)
# BltigYqt(0.375)
# Glqigent(0.75)
# GcKCgjnt(0.625)
# Gluigpnt(0.75)
# GguCgjnt(0.625)
# GluigRnt(0.75)
# Gluwgpnt(0.75)
# GluQxpnt(0.625)
# GluwgpnK(0.75)
# Gltwgjnt(0.625)
# Gltwgjnt(0.625)
# GcowgePt(0.5)
# GluigRnt(0.75)
# GlZQxpnt(0.625)
# GluQgpnt(0.75)
# GluigYqI(0.5)
# Gluwgjnt(0.75)
# Glqwgent(0.75)
# rlubUBZt(0.375)
# [71, 108, 113, 105, 103, 101, 110, 116]
# 5
# [71, 108, 117, 105, 103, 112, 110, 116]
# 5
# [71, 108, 117, 105, 103, 82, 110, 116]
# 1
# [71, 108, 117, 119, 103, 112, 110, 116]
# 5
# [71, 108, 113, 119, 103, 101, 110, 116]
# 0
# 染色体数63
# 染色体数63
# ルーレット選択[53 21 33  8 50 17  3 10 25  9 32 34 61 23 15 38 51 62  5 20 41 52 43 55
#  24  6 42 28 36 56]
# rlubUBZt(0.375)
# Gltwgjnt(0.625)
# GluQgpnt(0.75)
# GluQgpnt(0.75)
# GluwgePt(0.75)
# GluwgDnt(0.75)
# Gltwgjnt(0.625)
# GlKigent(0.75)
# GluQgpnt(0.75)
# GluwgpnK(0.625)
# GluigYqI(0.5)
# Gluigjnt(0.75)
# GluwgDnt(0.75)
# GluigRnt(0.75)
# GguCgjnt(0.625)
# Gluigpnt(0.75)
# Gcowgpnt(0.5)
# Rlqwgent(0.625)
# GCrugpnt(0.5138888888888888)
# Gltwgjnt(0.625)
# GlKigjnt(0.625)
# Gluigjnt(0.75)
# BltwgYNt(0.375)
# GluwgpnK(0.625)
# GlZQxpnt(0.625)
# GlKigent(0.75)
# Gltwgjnt(0.625)
# Rlqwgent(0.75)
# ...
#  10 31  4 18 45 22]
# fluzgent(0.75)
# Gluwgent(0.875)
# Gluwgent(0.875)
# GluwgeEt(0.75)
# GluwgRnt(0.75)
# GluwgOnt(0.75)
# Guuwgynt(0.625)
# fluzgent(0.75)
# GRuwgedt(0.625)
# GRuwgRnt(0.625)
# GluwgRnt(0.75)
# fluzgent(0.75)
# GRuwgedt(0.75)
# uluwzRHt(0.5)
# uluwgRHt(0.5)
# GluwgFbt(0.625)
# GluwgObt(0.625)
# fluigent(0.75)
# GluwgRjt(0.75)
# GNuwghnt(0.625)
# fluigent(0.75)
# GluwgRnt(0.75)
# Gluwgznt(0.75)
# GluwgeEt(0.75)
# Gluwgent(0.875)
# GluwgOnt(0.75)
# GluwgRnt(0.75)
# fluzgent(0.75)
# GRMwgRnt(0.5)
# GluwgRnt(0.75)
# [71, 108, 117, 119, 103, 101, 110, 116]
# 5
# [71, 82, 117, 119, 103, 101, 100, 116]
# 7
# [71, 108, 117, 119, 103, 70, 98, 116]
# 0
# [71, 78, 117, 119, 103, 104, 110, 116]
# 0
# [102, 108, 117, 105, 103, 101, 110, 116]
# 7
# [71, 108, 117, 119, 103, 122, 110, 116]
# 2
# 染色体数64
# 染色体数64
# ルーレット選択[31  4 23 54  7 27 63  1 25 17  9 45 20 19 21  2 35 48 24  8 61  0 39 22
#   3 40 56 49 52 26]
# fluwgent(0.75)
# GluwgRnt(0.75)
# GluwgeEt(0.75)
# Gluwgedt(0.75)
# fluzgent(0.75)
# fluzgent(0.75)
# GlSwgznt(0.625)
# GluwgHnt(0.875)
# GluwgOnt(0.75)
# fluigenw(0.75)
# GRuwgRnt(0.625)
# fluigent(0.75)
# fluigenw(0.75)
# tNuwghnt(0.625)
# GluwgRnt(0.75)
# Gluwgent(0.875)
# GluwgFbt(0.625)
# GNuwghnt(0.625)
# Gluwgent(0.875)
# GRuwgedZ(0.625)
# tNuwghnt(0.5)
# fluzgent(0.75)
# Gluwgent(0.875)
# GlSwgznt(0.75)
# GluwgeEt(0.75)
# GluwzRjt(0.5)
# Guuwgent(0.75)
# fluigent(0.75)
# fluzgeEt(0.625)
# GluwgRnt(0.75)
# [71, 108, 117, 119, 103, 79, 110, 116]
# 3
# [102, 108, 117, 105, 103, 101, 110, 119]
# 0
# [71, 108, 117, 119, 103, 82, 110, 116]
# 1
# [71, 108, 117, 119, 103, 70, 98, 116]
# 7
# 染色体数62
# 染色体数62
# ルーレット選択[12 58 56 13 15 39 21 43 33 53 32 49 40 42 46 17  2 35  8 30 23 19 11 47
#  29 44 54 48 36 26]
# Nluigenw(0.75)
# GluAgOnt(0.75)
# tNuwgent(0.625)
# tNuwghnt(0.625)
# Gluwgent(0.875)
# GluwgRnt(0.75)
# fluzgent(0.75)
# GluzgRjt(0.625)
# Gluwgent(0.875)
# Gluwgent(0.875)
# fluigenw(0.625)
# GNuwghnt(0.625)
# Gluigent(0.875)
# fluwzeEt(0.5)
# Gluzgent(0.875)
# GNuwghnt(0.625)
# GluwgeEt(0.75)
# fluigenw(0.625)
# GluAgOnt(0.75)
# fluwgznt(0.625)
# GlSwgznt(0.75)
# GRuwgedZ(0.625)
# fluigent(0.75)
# fuuwgent(0.625)
# GluwgRnt(0.75)
# GluwgeEt(0.75)
# Gluzgent(0.875)
# GlSwgznt(0.625)
# Gluwgent(0.875)
# Guuwgent(0.75)
# [71, 108, 117, 119, 103, 101, 110, 116]
# 1
# [71, 108, 117, 119, 103, 82, 110, 116]
# 2
# [102, 108, 117, 122, 103, 101, 110, 116]
# 6
# [102, 108, 117, 119, 122, 101, 69, 116]
# 3
# [71, 78, 117, 119, 103, 104, 110, 116]
# 5
# [102, 108, 117, 105, 103, 101, 110, 119]
# 7
# [71, 108, 117, 65, 103, 79, 110, 116]
# 4
# [71, 108, 117, 119, 103, 101, 110, 116]
# 4
# 染色体数66
# 染色体数66
# ルーレット選択[56 38  7 21 46 48 27 36 26 22 24 11 58 31 25 50 55 63 54  9 28  0  3 30
#  33  4 62  2  5 17]
# Guuwgent(0.75)
# Gluwgent(0.875)
# GluzgRjt(0.625)
# GRuwgedZ(0.625)
# fluwgent(0.75)
# Gluzgent(0.875)
# GlSwgznt(0.625)
# GlSwgznt(0.625)
# Gluzgent(0.875)
# fluigent(0.75)
# GluwgRnt(0.75)
# GNuwghnt(0.625)
# Gguwgent(0.75)
# Gluigent(0.875)
# GluwgeEt(0.75)
# Gluigent(0.875)
# GluAgOnt(0.75)
# fluigenC(0.625)
# Gluwgent(0.875)
# Gluwgent(0.875)
# Gluwwent(0.875)
# Nluigenw(0.75)
# tNuwghnt(0.625)
# NluwgeEw(0.5)
# Gluwgent(0.875)
# Gguwgent(0.875)
# GNuwgUnt(0.625)
# tNuwgent(0.625)
# GljwgRnt(0.75)
# fluigenC(0.625)
# [71, 108, 117, 122, 103, 82, 106, 116]
# 7
# [102, 108, 117, 105, 103, 101, 110, 67]
# 3
# [78, 108, 117, 105, 103, 101, 110, 119]
# 0
# [116, 78, 117, 119, 103, 104, 110, 116]
# 7
# [78, 108, 117, 119, 103, 101, 69, 119]
# 7
# [71, 108, 117, 119, 103, 101, 110, 116]
# 4
# 染色体数58
# 染色体数58
# ルーレット選択[ 5 40 44 45 27 51  6 21 41 18 57  4 12  0 39 11 46 54  3 16 22 48 42  9
#  55 35 49 43 14 38]
# Gluzgent(0.875)
# Guuwgent(0.75)
# Gluigent(0.875)
# Gluwwent(0.75)
# tNuwgent(0.625)
# Gluigent(0.875)
# GlSwgznt(0.625)
# vluigenw(0.75)
# GlSwgznt(0.625)
# Gluwgent(0.875)
# Gluwzent(0.75)
# fluwgent(0.75)
# Gguwgent(0.75)
# Guuwgent(0.75)
# Gluwgent(0.875)
# GNuwghnt(0.625)
# GNuzgUnt(0.625)
# vluigenw(0.625)
# GRuwgedZ(0.625)
# GluAgOnt(0.75)
# tNuwghnx(0.625)
# fluwgent(0.75)
# Gluigent(0.875)
# fluigent(0.75)
# tNuwghnx(0.3888888888888889)
# GluAgent(0.875)
# fluigenC(0.625)
# fluwgenC(0.625)
# GluwgeEt(0.75)
# GlSwgznt(0.625)
# [71, 108, 117, 122, 103, 101, 110, 116]
# 2
# [71, 117, 117, 119, 103, 101, 110, 116]
# 6
# [71, 108, 83, 119, 103, 122, 110, 116]
# 6
# [71, 117, 117, 119, 103, 101, 110, 116]
# 5
# [71, 108, 117, 119, 103, 101, 110, 116]
# 0
# [118, 108, 117, 105, 103, 101, 110, 119]
# 5
# [116, 78, 117, 119, 103, 104, 110, 120]
# 0
# [102, 108, 117, 119, 103, 101, 110, 116]
# 3
# [71, 108, 117, 105, 103, 101, 110, 116]
# 3
# [102, 108, 117, 119, 103, 101, 110, 67]
# 1
# 染色体数64
# 染色体数64
# ルーレット選択[39 20 16 62 63  7 26  2 58 29  4 46 42 17 55 56 31  0 12  3 27 34 52 50
#  28 40 37  6 33  1]
# GRuwgent(0.75)
# fNuwghnx(0.625)
# GNuzgUnt(0.625)
# GluVgent(0.875)
# fduwgenC(0.5)
# vluigPnw(0.75)
# fluigenC(0.625)
# Gluigent(0.875)
# Wluwgent(0.75)
# GlSwgznt(0.625)
# tNuwgent(0.625)
# vluigent(0.75)
# fluwgenC(0.625)
# vluigPnw(0.625)
# Guuwgeit(0.625)
# GlSwgzXt(0.5)
# GluigOnt(0.75)
# GlAzgent(0.875)
# Gguwgent(0.75)
# Gluwwent(0.75)
# fduwgenC(0.625)
# Gluwzent(0.75)
# GluwgeEt(0.75)
# GNuzgUnt(0.625)
# GluwgeEt(0.75)
# Guuwgent(0.75)
# fluwgent(0.75)
# GlSwgzXt(0.625)
# Gluwgent(0.875)
# Guuwgeit(0.75)
# [71, 82, 117, 119, 103, 101, 110, 116]
# 7
# [102, 78, 117, 119, 103, 104, 110, 120]
# 3
# [71, 108, 117, 86, 103, 101, 110, 116]
# 4
# [102, 108, 117, 105, 103, 101, 110, 67]
# 6
# [71, 108, 117, 119, 119, 101, 110, 116]
# 6
# [71, 108, 117, 119, 122, 101, 110, 116]
# 1
# [71, 108, 83, 119, 103, 122, 88, 116]
# 0
# 染色体数63
# 染色体数63
# ルーレット選択[14 35 29 17  4  3  8 57 34  1  5 27  0 60 44 11 24 62 56 52 43 42 26 20
#  38 49 46 50 16 22]
# Guuwgeit(0.625)
# GuuwgOnt(0.625)
# Guuwgeit(0.75)
# GlAzgent(0.875)
# fduwgenC(0.5)
# GluVuent(0.875)
# Wluwgent(0.75)
# fNupghnx(0.375)
# Gluigent(0.875)
# fNupghnx(0.625)
# vluigPnw(0.75)
# YlSwgzXt(0.625)
# GRuwgenm(0.75)
# Gluwweot(0.625)
# Gluwgent(0.875)
# vluigent(0.75)
# GluwgeEt(0.75)
# YlSwgzXt(0.375)
# GRuwgenm(0.625)
# Gguwgent(0.75)
# GluVgent(0.875)
# GNuzgUnt(0.625)
# fluwgent(0.75)
# fduwgenC(0.625)
# GNuwgeit(0.625)
# vluwgenw(0.625)
# tNuwgent(0.625)
# Gluwzent(0.75)
# GluigOnt(0.75)
# GluwgeEt(0.75)
# [102, 108, 117, 119, 103, 101, 110, 116]
# 0
# [71, 78, 117, 119, 103, 101, 105, 116]
# 2
# 染色体数58
# 染色体数58
# ルーレット選択[40  0 29 22 56 21 11 30 53 37 26 19 34 35  3  9 15  4 16 46 12 13 17 51
#   2 18 42  1 36  5]
# Gluwgent(0.875)
# Guuwgeit(0.625)
# GluwgeEt(0.75)
# Aluwgent(0.75)
# Aluwgent(0.75)
# GNuzgUnt(0.625)
# YlSwgzXt(0.625)
# GlupgeEt(0.75)
# fNuVghnx(0.375)
# YlSwgeXt(0.5)
# tNuwgent(0.625)
# Gguwgent(0.75)
# GluzgOnt(0.75)
# GNuigUnt(0.625)
# GlAzgent(0.875)
# fNupghnx(0.625)
# vluigent(0.75)
# fduwgenC(0.5)
# GluwgeEt(0.75)
# GRuwgenm(0.625)
# GRuwgenm(0.75)
# Gluwweot(0.625)
# YlSwgzXt(0.375)
# vluigent(0.75)
# Guuwgeit(0.75)
# GRuwgenm(0.625)
# tluwgent(0.75)
# GuuwgOnt(0.625)
# Wluwgznt(0.625)
# GluVuent(0.875)
# [71, 78, 117, 105, 103, 85, 110, 116]
# 3
# 染色体数57
# 染色体数57
# ルーレット選択[37 33 29 50 43 51 38 20 24  2 14 52 48 31 32  4 22 42 13  0 47 18 44 21
#  49 17 16 23 54 11]
# YlSwgeXt(0.5)
# fuuwgeit(0.5)
# GluVuent(0.875)
# GluVgOnt(0.75)
# Gluigenm(0.75)
# Gluzuent(0.75)
# Yluwgent(0.75)
# GRuwgenm(0.75)
# Guuwgeit(0.75)
# GluwgeEt(0.75)
# GlAzgent(0.875)
# AluwgOnt(0.625)
# Gluwgent(0.875)
# Gluwweot(0.625)
# GNuVghnx(0.5)
# Aluwgent(0.75)
# YlSwgzXt(0.375)
# vRuwgent(0.625)
# GNuqgUnt(0.625)
# Gluwgent(0.875)
# GluzgUnt(0.75)
# GluwgeEt(0.75)
# Wluwgznt(0.625)
# Gluwweot(0.625)
# GlupgeEt(0.75)
# fduwgenC(0.5)
# vluigent(0.75)
# vluigent(0.75)
# Guuigeit(0.625)
# Gguwgent(0.75)
# [71, 108, 117, 119, 103, 101, 69, 116]
# 4
# [71, 108, 65, 122, 103, 101, 110, 116]
# 2
# [71, 108, 117, 119, 103, 101, 69, 116]
# 6
# [87, 108, 117, 119, 103, 122, 110, 116]
# 2
# [71, 103, 117, 119, 103, 101, 110, 116]
# 0
# 染色体数61
# 染色体数61
# ルーレット選択[19 51  3 12  7 30  2 22 15 41 36 21 52 40 26 27 33 60 32 42 31 23  6  8
#  11  1 46 39 37 35]
# Gluwgent(0.875)
# Gluwgeot(0.75)
# GluVgOnt(0.75)
# Gluwgent(0.875)
# GRuwgenm(0.75)
# WluwgOnt(0.625)
# GluVuent(0.875)
# WlXwgznt(0.625)
# Aluwgent(0.75)
# Auuwgent(0.625)
# Gluwuent(0.75)
# GluwgeWt(0.75)
# GluwgUnt(0.75)
# Gluigeit(0.75)
# vluigent(0.75)
# vluigent(0.75)
# flupgenC(0.625)
# Eguwgent(0.625)
# GduwgeEt(0.625)
# GlAzgent(0.75)
# Aluwgznt(0.625)
# Gluwweot(0.625)
# Yluwgent(0.75)
# Guuwgeit(0.75)
# AluwgOnt(0.625)
# fuuwgeit(0.5)
# fuuwgeix(0.375)
# vRuigent(0.625)
# GluVgent(0.875)
# GRuwgenm(0.625)
# [71, 82, 117, 119, 103, 101, 110, 109]
# 4
# [71, 108, 117, 119, 117, 101, 110, 116]
# 7
# [102, 117, 117, 119, 103, 101, 105, 116]
# 6
# 染色体数53
# 染色体数53
# ルーレット選択[10  6 22  4 30  3 11 46 33  1 28 21 16 36  0 48 39 14 24  8 32 40 51 50
#  18 34 41 19  9 45]
# GluwuenT(0.75)
# GluVuent(0.875)
# Yluwgent(0.75)
# GRuwWenm(0.75)
# Gguwgent(0.75)
# Gluwgent(0.875)
# GluwgeWt(0.75)
# Aluwwent(0.625)
# vluigent(0.75)
# Gluwgeot(0.75)
# GluVgent(0.875)
# Gluwweot(0.625)
# flupgenC(0.625)
# Gluzgent(0.875)
# Gluwgent(0.875)
# GluwgUnt(0.75)
# Gluwgeot(0.75)
# vluigent(0.75)
# AluwgOnt(0.625)
# Aluwgent(0.75)
# vluigent(0.75)
# Guuwgent(0.75)
# GluwuenT(0.625)
# GRuwWenm(0.5)
# GduwgeEt(0.625)
# GluwgeEt(0.75)
# Gluwgeit(0.75)
# GlAzgent(0.75)
# Auuwgent(0.625)
# Glupgenm(0.75)
# [71, 108, 117, 119, 117, 101, 110, 84]
# 7
# [71, 82, 117, 119, 87, 101, 110, 109]
# 6
# [71, 103, 117, 119, 103, 101, 110, 116]
# 5
# [102, 108, 117, 112, 103, 101, 110, 67]
# 2
# [118, 108, 117, 105, 103, 101, 110, 116]
# 3
# [118, 108, 117, 105, 103, 101, 110, 116]
# 1
# [71, 108, 117, 119, 103, 101, 105, 116]
# 4
# [71, 108, 117, 112, 103, 101, 110, 109]
# 6
# 染色体数60
# 染色体数60
# ルーレット選択[20  1 59 31 14 22 58 10 48 45  9 41 38  7 24  0 17 36 19  5 33 54  6 49
#  11 39 43 27  8 40]
# vSuigent(0.75)
# GluVuent(0.875)
# Glupgexm(0.625)
# GluwWenm(0.625)
# Gluwgent(0.875)
# Gluwuenn(0.625)
# GluwReit(0.625)
# GluVgent(0.875)
# fRuwWenC(0.375)
# Yluwgent(0.75)
# Gluwgeot(0.75)
# Gluwgeot(0.75)
# GluwgeWt(0.75)
# Aluwwent(0.625)
# GduwgeEt(0.625)
# Gluwuenn(0.75)
# vluigent(0.75)
# GluwgOnt(0.75)
# Aluwgent(0.75)
# Gluwgent(0.875)
# vluigent(0.75)
# Gguwghnt(0.625)
# GluwgeWt(0.75)
# Glupgenm(0.75)
# Gluwweot(0.625)
# GluwgeEt(0.75)
# vluigeot(0.625)
# GlAzgent(0.75)
# vluigent(0.75)
# Gluwgent(0.875)
# [102, 82, 117, 119, 87, 101, 110, 67]
# 5
# [89, 108, 117, 119, 103, 101, 110, 116]
# 3
# [71, 108, 117, 119, 103, 101, 111, 116]
# 1
# [71, 108, 117, 119, 117, 101, 110, 110]
# 6
# [71, 108, 117, 119, 103, 79, 110, 116]
# 5
# [118, 108, 117, 105, 103, 101, 110, 116]
# 1
# [71, 108, 117, 119, 119, 101, 111, 116]
# 4
# [71, 108, 65, 122, 103, 101, 110, 116]
# 6
# 染色体数62
# 染色体数62
# ルーレット選択[28  2 27 22  9 11 56 18 21 15 59 51  7 57 39 20 17 52 45 37 29 46 30 26
#  42 58 47 16 35  5]
# vluigent(0.75)
# Glupgexm(0.625)
# GlAzgeDt(0.75)
# GluwgeWt(0.75)
# Ylusgent(0.75)
# Gluwgeot(0.75)
# Gpuwgeot(0.625)
# Aluwgent(0.75)
# Gguwghnt(0.625)
# Gluwueen(0.75)
# vuuigent(0.625)
# Gluwgenn(0.75)
# GluVgent(0.875)
# Gluwueen(0.5277777777777778)
# GluwgeWt(0.75)
# vuuigent(0.75)
# Gluwgjnt(0.75)
# vluigent(0.75)
# GluwRent(0.75)
# Gluwgeot(0.75)
# Gluwgent(0.875)
# GluwgeWt(0.75)
# vluwuent(0.625)
# vluigeot(0.625)
# vSuigent(0.625)
# Gluwgjnt(0.75)
# Gluwgent(0.875)
# vluigent(0.75)
# Gluwgeot(0.75)
# Gluwueen(0.625)
# [71, 108, 117, 112, 103, 101, 120, 109]
# 4
# [71, 108, 65, 122, 103, 101, 68, 116]
# 3
# [89, 108, 117, 115, 103, 101, 110, 116]
# 7
# [71, 108, 117, 119, 103, 101, 111, 116]
# 2
# [71, 112, 117, 119, 103, 101, 111, 116]
# 3
# [71, 108, 117, 119, 103, 106, 110, 116]
# 5
# [71, 108, 117, 119, 82, 101, 110, 116]
# 0
# [71, 108, 117, 119, 103, 101, 111, 116]
# 3
# [118, 108, 117, 105, 103, 101, 111, 116]
# 7
# [71, 108, 117, 119, 103, 101, 110, 116]
# 1
# 染色体数62
# 染色体数62
# ルーレット選択[51 53 61  4 12 15 24 25 38 57 40 42 33 17 30 26 36  7 34  8 44 60 31 10
#  56 39 50  9 43 20]
# GSuwgjnt(0.625)
# GlAzgeDt(0.625)
# GAuwgent(0.75)
# YlusgenP(0.75)
# GluVgent(0.875)
# vuuigent(0.75)
# vSuigent(0.625)
# Gluwgont(0.75)
# Gluwgent(0.875)
# Gluwgont(0.75)
# GluwgeWt(0.75)
# Gluwgent(0.875)
# Gluwgent(0.875)
# vluigent(0.75)
# Ylusgent(0.75)
# GAuwgent(0.875)
# vuuigent(0.625)
# Aluwgent(0.75)
# Gluwuent(0.75)
# Gguwghnt(0.625)
# Gluwgent(0.875)
# vluigeoj(0.5)
# vluigent(0.75)
# vuuigent(0.625)
# GpuEgeot(0.625)
# vluigeot(0.625)
# vluigent(0.75)
# Gluwueen(0.75)
# Gluwgenn(0.75)
# Gluwgent(0.875)
# [71, 65, 117, 119, 103, 101, 110, 116]
# 0
# [89, 108, 117, 115, 103, 101, 110, 80]
# 7
# [71, 108, 117, 119, 103, 101, 110, 116]
# 3
# [71, 108, 117, 119, 103, 101, 110, 116]
# 4
# [118, 117, 117, 105, 103, 101, 110, 116]
# 1
# [65, 108, 117, 119, 103, 101, 110, 116]
# 7
# 染色体数62
# 染色体数62
# ルーレット選択[39 10 48 31 49 36 57  8 33 41 14 20 50 56 23 44  9 53 22 24  6 18 37 13
#   1 47 19 11 32  7]
# GlAzgeDt(0.625)
# GluwgeWt(0.75)
# GAuwgeWt(0.625)
# Gluwgjnt(0.75)
# Gluwgent(0.875)
# Gluwgent(0.875)
# YlusgenR(0.625)
# Gluwgent(0.875)
# Gluwgeen(0.6527777777777778)
# Gluwuent(0.75)
# Ylusgent(0.75)
# Gluwgent(0.875)
# Yuuigent(0.625)
# MAuwgent(0.625)
# vuuigent(0.625)
# Glusgenn(0.75)
# Gluwgont(0.75)
# vluigenj(0.625)
# vluigent(0.75)
# GpuEgeot(0.625)
# vSuigent(0.625)
# Gluwuent(0.75)
# Gluwgent(0.875)
# vluigent(0.75)
# GlAzgeDt(0.625)
# GpuEgent(0.75)
# Gguwghnt(0.625)
# Gluagent(0.875)
# vluiuent(0.625)
# Gluwgont(0.75)
# [71, 108, 65, 122, 103, 101, 68, 116]
# 5
# [71, 108, 117, 119, 103, 101, 87, 116]
# 3
# [71, 108, 117, 119, 103, 106, 110, 116]
# 3
# [71, 108, 117, 119, 103, 101, 110, 116]
# 2
# [89, 108, 117, 115, 103, 101, 110, 82]
# 1
# [71, 108, 117, 119, 103, 101, 110, 116]
# 7
# [71, 108, 117, 119, 103, 111, 110, 116]
# 0
# [118, 108, 117, 105, 103, 101, 110, 106]
# 7
# [118, 108, 117, 105, 103, 101, 110, 116]
# 7
# [71, 108, 117, 97, 103, 101, 110, 116]
# 7
# [118, 108, 117, 105, 117, 101, 110, 116]
# 0
# [122, 108, 117, 119, 103, 111, 110, 116]
# 3
# 染色体数66
# 染色体数66
# ルーレット選択[28 55  8  3  5 33 45 47 20 50 46 36  1 48 15 54 42 16  9 65 60 17 59 38
#  11 40 27 43 21  2]
# Hluiuent(0.625)
# GlufgeWt(0.75)
# Gluwgeen(0.6527777777777778)
# GluQgjnt(0.75)
# Gluwgent(0.875)
# Glusgent(0.875)
# Gluwgenn(0.75)
# GlAzgent(0.75)
# vSuigent(0.625)
# Gluwgeen(0.6527777777777778)
# GluwgjDt(0.625)
# Gluwgent(0.875)
# GlufgeWt(0.75)
# vuuigent(0.625)
# Glusgenn(0.75)
# GlAzgRDt(0.5)
# GAuwgent(0.75)
# zluagont(0.75)
# Gluwuent(0.75)
# zluagont(0.625)
# zluagont(0.625)
# vluigenH(0.625)
# Gluwgenv(0.75)
# vSuwgent(0.625)
# Gluwgenv(0.875)
# vluigent(0.75)
# Gluagenp(0.875)
# GluwgeWt(0.75)
# Gluwuent(0.75)
# GAuwgeWt(0.625)
# [71, 108, 117, 81, 103, 106, 110, 116]
# 2
# [71, 108, 117, 119, 103, 101, 110, 116]
# 0
# [71, 108, 117, 119, 103, 101, 110, 110]
# 0
# [118, 83, 117, 105, 103, 101, 110, 116]
# 1
# [71, 108, 117, 119, 103, 106, 68, 116]
# 0
# [71, 108, 65, 122, 103, 82, 68, 116]
# 4
# 染色体数64
# 染色体数64
# ルーレット選択[53 46  2 15 39 60 21  5 29 31 42 28 25 26 45 30  4 10 24 54 52 40 16 61
#  20 12 55 43 37 57]
# GluwgeWt(0.75)
# Gluwgenv(0.75)
# Gluwgeen(0.6527777777777778)
# GlAzpRDt(0.5)
# vluigenH(0.625)
# tluwgenn(0.6388888888888888)
# vluigenH(0.625)
# Glusgent(0.875)
# GAuwgeWt(0.625)
# Glusgent(0.875)
# GlAzgent(0.75)
# Gluwuent(0.75)
# vluigent(0.75)
# Gluagenp(0.875)
# vluwgent(0.75)
# Gluwuent(0.75)
# Rluwgent(0.875)
# EluwgjDt(0.625)
# Gluwgenv(0.875)
# Gluagont(0.75)
# GAuwuent(0.625)
# GlAzgenp(0.625)
# GAuwgent(0.75)
# vmuigent(0.625)
# zluagont(0.625)
# GlufgeWt(0.75)
# zlufgeWt(0.625)
# Gluwgent(0.875)
# vAuwgent(0.625)
# Gluageen(0.6527777777777778)
# [116, 108, 117, 119, 103, 101, 110, 110]
# 4
# [118, 108, 117, 105, 103, 101, 110, 72]
# 5
# [71, 108, 65, 122, 103, 101, 110, 116]
# 6
# [118, 108, 117, 119, 103, 101, 110, 116]
# 5
# [71, 108, 117, 119, 103, 101, 110, 118]
# 6
# [71, 108, 117, 97, 103, 111, 110, 116]
# 2
# [71, 108, 117, 102, 103, 101, 87, 116]
# 3
# [71, 108, 117, 119, 103, 101, 110, 116]
# 1
# 染色体数66
# 染色体数66
# ルーレット選択[ 7 38 25 54 30  4  6 18  3 17 60 24 43 27 63 19 29 14 20 42 51 56  9 62
#  16 45 32 23 59 10]
# Glusgent(0.875)
# vluigenH(0.625)
# GluggeWt(0.75)
# Glusgent(0.875)
# zlusgeWt(0.625)
# vluigenH(0.625)
# vluiggnH(0.625)
# Gluwgehv(0.875)
# GlAzpRDt(0.5)
# EluwgjDt(0.625)
# GlAzgegt(0.625)
# zluagont(0.625)
# Gluwgeev(0.6388888888888888)
# GYuwgent(0.875)
# GlFagont(0.625)
# GlFagont(0.75)
# Gluageen(0.6527777777777778)
# vluwgrnt(0.75)
# GAuwuent(0.625)
# Gluwgenn(0.75)
# Gluagenp(0.75)
# Gluwuenv(0.625)
# Glusgent(0.875)
# Gluwgehv(0.625)
# Rluwgent(0.875)
# Gluagont(0.75)
# vluigeDH(0.5)
# vmuigent(0.625)
# vluiggnH(0.5)
# GlAzgegt(0.75)
# [118, 108, 117, 105, 103, 101, 110, 72]
# 3
# [71, 108, 117, 115, 103, 101, 110, 116]
# 5
# [71, 108, 117, 119, 103, 101, 104, 118]
# 1
# [71, 108, 65, 122, 112, 82, 68, 116]
# 7
# [69, 108, 117, 119, 103, 106, 68, 116]
# 2
# [71, 108, 117, 119, 103, 101, 101, 118]
# 3
# [71, 108, 70, 97, 103, 111, 110, 116]
# 5
# 染色体数61
# 染色体数61
# ルーレット選択[60 22 10  9  2 39 11 17 27 26 16  8 54 23 25 21 29 42  0 15 46 44  5 55
#  56 34 28 38 41 57]
# GlFagRnt(0.625)
# Glusgent(0.875)
# GlAzgegt(0.625)
# ElHwgjDt(0.625)
# GluggeWt(0.75)
# vluigenH(0.625)
# zluagont(0.625)
# vluwgrnt(0.75)
# vmuigent(0.625)
# vluigeDH(0.5)
# Gluageen(0.6527777777777778)
# GlAzpRDM(0.5)
# vluhgenH(0.625)
# GEuwgehv(0.625)
# Gluagont(0.75)
# Gluwuenv(0.625)
# GlAzgegt(0.75)
# Gluageen(0.6527777777777778)
# Glusgent(0.875)
# GlFagRnt(0.75)
# vluwggnH(0.5)
# vluwgrnt(0.625)
# vluigenH(0.625)
# Glusgrnt(0.75)
# GEuwgehv(0.5)
# vluiggnH(0.5)
# vluiggnH(0.5)
# vluigeDH(0.5)
# Gluwgehv(0.625)
# GlAzpRDM(0.25)

# %% [markdown]
# グラフにプロット

# %%
import matplotlib

# %% [markdown]
# テスト

# %%
from abc import ABC, ABCMeta, abstractmethod
class AbstractGA(ABC):
    # Setting=[Name, MaxGeneration, Population, EliteCount, MaxStagnationGeneration, GenesDimension ...]
    def __init__(self, parameters):
        self.max_generation = parameters["maxGeneration"]
        self.population = parameters["population"]
        self.crossover_probability = parameters["crossover_probability"]
        self.mutation_probability = parameters["mutation_probability"]
        self.generation =[]
        self.new_generation = []

    # 遺伝子をランダムに作成。一つの個体に対してself.GenesDimensionの数だけ次元を広げる
    def create_init_gene(self):
        genes = list()
        tmp = list()
        for child in range(self.Population):
            for _ in range(self.GenesDimension):
                tmp.append(random.randint(-30,30))
            genes.append(tmp)
            tmp = list()
        # genes.shape=(self.Population, self.GenesDimension)
        return genes



    # 遺伝子の評価
    def evaluate(self, genes, goal):
        # 評価したデータは辞書型で保持。(key, value)=(child_id, fitness)
        evaluated_data = dict()
        for child in range(self.Population):
            # 適応度は高い方がよい（最大で1となるように調整。)
            fitness = 1/(self.eval_func(genes[child], goal) + 1)
            evaluated_data[child] = fitness
        # 評価値に沿って降順ソート
        evaluated_data = dict(sorted(evaluated_data.items(),reverse=True, key=lambda x:x[1]))
        return evaluated_data

    # evaluateの補助関数
    # 目標値との差分を計算
    def eval_func(self, gene, goal):
        sum_value = 0
        # self.GenesDimension空間における原点からのユークリッド距離を計算。
        for id in range(len(gene)):
            sum_value += gene[id]**2
        return abs(np.sqrt(sum_value) - goal)   # goal(目標値)とのずれを計算。


    # genesデータや適応度などを外部ファイルに出力
    def Out_data(self, genes, evaluated_data, generation):
        # 遺伝子の出力(並び替え前), csvと同じカンマ区切り
        gene_path = "./Out/" + str(generation) + ".gene"
        with open(gene_path, "w") as file:
            for child in range(len(genes)):
                for id in range(len(genes[child])):
                    if id==len(genes[child])-1:
                        print(str(genes[child][id]), file=file)
                    else:
                        print(str(genes[child][id]), end=",", file=file)
        # 適応度の出力（並び替え後）,csvと同じカンマ区切り
        fitness_path = "./Out/" + str(generation) + ".fit"
        with open(fitness_path, "w") as file:
            for id, fitness in evaluated_data.items():
                print(str(id) +","+ str(fitness), file=file)


    # 適応度の高い上位個体を保存
    def Save_elite(self, genes, evaluated_data):
        elite_id = list()
        elite_genes = list()
        # elite_idを辞書から取得
        for key in evaluated_data.keys():
            elite_id.append(key)
        # eliteの数だけ上から抽出
        for elite in range(self.EliteCount):
            elite_genes.append(genes[elite_id[elite]])

        return elite_genes




    # method==0: Expected value selection
    # method==1: Ranking selection
    # method==2: Tournament selection
    def select(self, method, genes, evaluated_data):
        # idとfitnessを個別にリストで保管
        id_list = list()
        fitness_list = list()
        Select_id = list()
        for id, fitness in evaluated_data.items():
            id_list.append(id)
            fitness_list.append(fitness)

        # 期待値選択
        if method==0:
            roulette = 360
            tmp_list = list()
            sum_fitness = sum(fitness_list) # 適応度の合計値を取得
            cumulative_fitness = np.cumsum(roulette*np.array(fitness_list)/sum_fitness) # 適応度の高さに応じて幅の広い一回転360度のテーブルを作成
            for child in range(self.Population - self.EliteCount):    # エリート以外の個体を作成するため、個体数 ー エリート個体数
                for _ in range(2):                                    # ２つの遺伝子を組み合わせるため繰り返す。
                    Fate_dice = random.uniform(0,360)                 # 0~360の間の運命のサイコロを振る
                    Hit_id = 0
                    while True:
                        if cumulative_fitness[Hit_id] >= Fate_dice:
                            break
                        else:
                            Hit_id += 1
                    tmp_list.append(id_list[Hit_id])
                Select_id.append(tmp_list)
                tmp_list = list()
        return Select_id



    # method==0: Uniform crossover
    # method==1: Multipoint crossover
    # method==2: Partial coincidence crossover
    def crossover(self, method, genes, Select_id):
        new_genes = list()
        # 次の世代のgenesをSelect_id[child][0]のid番号を使って作成
        for child in range(self.Population - self.EliteCount):
            new_genes.append(genes[Select_id[child][0]])

        if method==0:
            probability = 0.4
            for child in range(self.Population - self.EliteCount):
                for dim in range(len(genes[0])):
                    Fate_random = random.uniform(0,1)
                    if Fate_random <= probability:
                        new_genes[child][dim] = genes[Select_id[child][1]][dim]
        return new_genes



    def mutation(self, genes, Stagnation):
        probability = 0.4                          #突然変異をする確率
        serious_rate = Stagnation/(self.MaxGeneration - self.EliteCount)   # 停滞が大きくなれば突然変異する可能性も上げる
        serious_count = int(len(genes)*serious_rate)        # genes配列の大きさを掛けることで、配列のどこまでを突然変異与えるのか調整
        for child in range(serious_count):
            for dim in range(len(genes[0])):
                Fate_random = random.uniform(0,1)      # 0~1の乱数を取得
                if Fate_random <= probability:
                    genes[child][dim] += random.randint(-10,10) # -10~10の乱数を付与（決め打ち）
        return genes

# %% [markdown]
# ## サンプル

# %%
class GA:
    # Setting=[Name, MaxGeneration, Population, EliteCount, MaxStagnationGeneration, GenesDimension ...]
    def __init__(self, Setting):
        self.Name = Setting[0]
        self.MaxGeneration = Setting[1]
        self.Population = Setting[2]
        self.EliteCount = Setting[3]
        self.MaxStagnationGeneration = Setting[4]
        self.GenesDimension = Setting[5]

        os.makedirs("./Out/", exist_ok=True)

        print("\n GA start!! \n")


        # flag==0、print出力 flag==1、ファイル記述
    def get_parameter(self, flag=0, out_path="./"):
        # ファイル出力の際のパス
        out_path = out_path + "GA_parameter.txt"
        # 出力内容
        contents = [
                     f'GA_parameter!!\n',
                     f'Name: {self.Name}',
                     f'MaxGeneration: {self.MaxGeneration}',
                     f'Population: {self.Population}',
                     f'EliteCount: {self.EliteCount}',
                     f'GenesDimension: {self.GenesDimension}',
                                                                ]
        # flagにより出力先を変更
        if flag==0:
            for sentense in contents:
                print(sentense)
        elif flag==1:
            with open(out_path, mode="w") as file:
                for sentense in contents:
                    print(sentense, file=file)


    # GAを始める関数（というか、この中に処理ほとんど書いてるからmain関数みたいなもの？）
    def Start_GA(self):
        # 現在の世代
        generation = 0
        # 世代の停滞値
        Stagnation = 0
        # 目標値
        goal = 0
        # 一番適応度の良い遺伝子の軌跡
        top_genes = list()
        # 初期集団として遺伝子をランダムに作成。
        genes = self.make_genes()
        while(True):
            #　最大世代まで進むと終了
            if generation >= self.MaxGeneration:
                break
            else:
                # 適応度の評価
                evaluated_data = self.evaluate(genes, goal)
                # 遺伝子ファイルと適応度を外部に出力
                self.Out_data(genes, evaluated_data, generation)
                # 適応度の高い上位個体を保存
                elite_genes = copy.deepcopy(self.Save_elite(genes, evaluated_data))
                # 適応度の高い者同士を選択
                Select_id = self.select(0, genes, evaluated_data)
                # 交叉させて新しい遺伝子の作成
                genes = self.crossover(0, genes, Select_id)
                # 突然変異を与えて解探索領域を広げる
                genes = self.mutation(genes, Stagnation)
                # エリート遺伝子を加える
                genes[len(genes):len(genes)] = elite_genes
                # 一番適応度の良い個体を保存
                top_genes.append(elite_genes[0])
                # 第二世代以降において、適応度の停滞（適応度の一番良い値が更新されない）が最大停滞数を超えていればプログラムは終了。
                if len(top_genes)>=2:
                    if top_genes[-1]==top_genes[-2]:
                        # 最大停滞数を超えればアルゴリズムは終了
                        if Stagnation >= self.MaxStagnationGeneration:
                            exit()
                        else:
                            Stagnation += 1
                    else:
                        Stagnation = 0
                # 世代を進める
                generation +=1



    # 遺伝子をランダムに作成。一つの個体に対してself.GenesDimensionの数だけ次元を広げる
    def make_genes(self):
        genes = list()
        tmp = list()
        for child in range(self.Population):
            for _ in range(self.GenesDimension):
                tmp.append(random.randint(-30,30))
            genes.append(tmp)
            tmp = list()
        # genes.shape=(self.Population, self.GenesDimension)
        return genes



    # 遺伝子の評価
    def evaluate(self, genes, goal):
        # 評価したデータは辞書型で保持。(key, value)=(child_id, fitness)
        evaluated_data = dict()
        for child in range(self.Population):
            # 適応度は高い方がよい（最大で1となるように調整。)
            fitness = 1/(self.eval_func(genes[child], goal) + 1)
            evaluated_data[child] = fitness
        # 評価値に沿って降順ソート
        evaluated_data = dict(sorted(evaluated_data.items(),reverse=True, key=lambda x:x[1]))
        return evaluated_data

    # evaluateの補助関数
    # 目標値との差分を計算
    def eval_func(self, gene, goal):
        sum_value = 0
        # self.GenesDimension空間における原点からのユークリッド距離を計算。
        for id in range(len(gene)):
            sum_value += gene[id]**2
        return abs(np.sqrt(sum_value) - goal)   # goal(目標値)とのずれを計算。


    # genesデータや適応度などを外部ファイルに出力
    def Out_data(self, genes, evaluated_data, generation):
        # 遺伝子の出力(並び替え前), csvと同じカンマ区切り
        gene_path = "./Out/" + str(generation) + ".gene"
        with open(gene_path, "w") as file:
            for child in range(len(genes)):
                for id in range(len(genes[child])):
                    if id==len(genes[child])-1:
                        print(str(genes[child][id]), file=file)
                    else:
                        print(str(genes[child][id]), end=",", file=file)
        # 適応度の出力（並び替え後）,csvと同じカンマ区切り
        fitness_path = "./Out/" + str(generation) + ".fit"
        with open(fitness_path, "w") as file:
            for id, fitness in evaluated_data.items():
                print(str(id) +","+ str(fitness), file=file)


    # 適応度の高い上位個体を保存
    def Save_elite(self, genes, evaluated_data):
        elite_id = list()
        elite_genes = list()
        # elite_idを辞書から取得
        for key in evaluated_data.keys():
            elite_id.append(key)
        # eliteの数だけ上から抽出
        for elite in range(self.EliteCount):
            elite_genes.append(genes[elite_id[elite]])

        return elite_genes




    # method==0: Expected value selection
    # method==1: Ranking selection
    # method==2: Tournament selection
    def select(self, method, genes, evaluated_data):
        # idとfitnessを個別にリストで保管
        id_list = list()
        fitness_list = list()
        Select_id = list()
        for id, fitness in evaluated_data.items():
            id_list.append(id)
            fitness_list.append(fitness)

        # 期待値選択
        if method==0:
            roulette = 360
            tmp_list = list()
            sum_fitness = sum(fitness_list) # 適応度の合計値を取得
            cumulative_fitness = np.cumsum(roulette*np.array(fitness_list)/sum_fitness) # 適応度の高さに応じて幅の広い一回転360度のテーブルを作成
            for child in range(self.Population - self.EliteCount):    # エリート以外の個体を作成するため、個体数 ー エリート個体数
                for _ in range(2):                                    # ２つの遺伝子を組み合わせるため繰り返す。
                    Fate_dice = random.uniform(0,360)                 # 0~360の間の運命のサイコロを振る
                    Hit_id = 0
                    while True:
                        if cumulative_fitness[Hit_id] >= Fate_dice:
                            break
                        else:
                            Hit_id += 1
                    tmp_list.append(id_list[Hit_id])
                Select_id.append(tmp_list)
                tmp_list = list()
        return Select_id



    # method==0: Uniform crossover
    # method==1: Multipoint crossover
    # method==2: Partial coincidence crossover
    def crossover(self, method, genes, Select_id):
        new_genes = list()
        # 次の世代のgenesをSelect_id[child][0]のid番号を使って作成
        for child in range(self.Population - self.EliteCount):
            new_genes.append(genes[Select_id[child][0]])

        if method==0:
            probability = 0.4
            for child in range(self.Population - self.EliteCount):
                for dim in range(len(genes[0])):
                    Fate_random = random.uniform(0,1)
                    if Fate_random <= probability:
                        new_genes[child][dim] = genes[Select_id[child][1]][dim]
        return new_genes



    def mutation(self, genes, Stagnation):
        probability = 0.4                          #突然変異をする確率
        serious_rate = Stagnation/(self.MaxGeneration - self.EliteCount)   # 停滞が大きくなれば突然変異する可能性も上げる
        serious_count = int(len(genes)*serious_rate)        # genes配列の大きさを掛けることで、配列のどこまでを突然変異与えるのか調整
        for child in range(serious_count):
            for dim in range(len(genes[0])):
                Fate_random = random.uniform(0,1)      # 0~1の乱数を取得
                if Fate_random <= probability:
                    genes[child][dim] += random.randint(-10,10) # -10~10の乱数を付与（決め打ち）
        return genes
